# %%
# import packages 

import numpy as np
import os
import datetime
import time
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


# folder path and name
project_path = os.getcwd()
data_folder = os.path.join(project_path,"data_expanded")
pred_folder = os.path.join(data_folder,'data_forecast')
pv_data_path = os.path.join(project_path,'pv_data','pv_output_valid.pkl')

image_name_format = '%Y%m%d%H%M%S'

# Operating parameter
stack_height = 15 # 15 minute
forecast_horizon = 15 # 15 minutes ahead forecast
sampling_interval_all = [2]
output_img_shape = [64, 64, 3]

start_date = datetime.datetime(2017,3,9)
end_date = datetime.datetime(2017,12,31)

# Setting up test set
sunny_day = [(2017,3,14),(2017,5,20),(2017,6,4),(2017,7,6),(2017,8,19),(2017,10,7),(2017,11,1),(2017,12,26)]
cloudy_day = [(2017,3,15),(2017,5,24),(2017,7,5),(2017,9,6),(2017,9,22),(2017,11,4),(2017,12,29)]

sunny_datetime = [datetime.datetime(day[0],day[1],day[2]) for day in sunny_day]
cloudy_datetime = [datetime.datetime(day[0],day[1],day[2]) for day in cloudy_day]
test_dates = sunny_datetime + cloudy_datetime

# %%
test_dates
# Out:
# [datetime.datetime(2017, 3, 14, 0, 0),
#  datetime.datetime(2017, 5, 20, 0, 0),
#  datetime.datetime(2017, 6, 4, 0, 0),
#  datetime.datetime(2017, 7, 6, 0, 0),
#  datetime.datetime(2017, 8, 19, 0, 0),
#  datetime.datetime(2017, 10, 7, 0, 0),
#  datetime.datetime(2017, 11, 1, 0, 0),
#  datetime.datetime(2017, 12, 26, 0, 0),
#  datetime.datetime(2017, 3, 15, 0, 0),
#  datetime.datetime(2017, 5, 24, 0, 0),
#  datetime.datetime(2017, 7, 5, 0, 0),
#  datetime.datetime(2017, 9, 6, 0, 0),
#  datetime.datetime(2017, 9, 22, 0, 0),
#  datetime.datetime(2017, 11, 4, 0, 0),
#  datetime.datetime(2017, 12, 29, 0, 0)]

# %%
def find_idx_with_dates(all_times,test_dates):
    idx=[]
    for test_day in test_dates:
        test_day_end = test_day + datetime.timedelta(days = 1)
        idx+=np.nonzero((all_times>test_day)*(all_times<test_day_end))[0].tolist()
    return idx

# This two function does the same thing. Just that one is for np, the other for pd.

def find_time_within_nparray(time_array,time_point):
    probable_idx = np.searchsorted(time_array,time_point)
    
    # If the time point is after all the time in pv_data
    if probable_idx == len(time_array):
        return None   
    
    # See if the time point is actually a match 
    if time_array[probable_idx]== time_point: 
        return probable_idx
        
    else:
        return None

def find_time_within_pdseries(time_array,time_point):
    probable_idx = np.searchsorted(time_array,time_point)
    
    # If the time point is after all the time in pv_data
    if probable_idx == len(time_array):
        return None   
    
    # See if the time point is actually a match 
    if time_array[probable_idx] == time_point: 
        return probable_idx
        
    else:
        return None

# %%
def store_trainval_test(all_times,image_log,pv_log,pv_pred,pred_folder):
    
    ## Splitting into Trainval and Test set 
    idx_test = find_idx_with_dates(all_times,test_dates)
    image_log_test = image_log[idx_test]
    pv_log_test = pv_log[idx_test]
    pv_pred_test = pv_pred[idx_test]
    times_test = all_times[idx_test]

    # the rest become the trainval set
    mask_trainval = np.ones_like(pv_pred,dtype = bool)
    mask_trainval[idx_test] = 0
    image_log_trainval = image_log[mask_trainval]
    pv_log_trainval = pv_log[mask_trainval]
    pv_pred_trainval = pv_pred[mask_trainval]
    times_trainval = all_times[mask_trainval]
    
    print("times_trainval.shape",times_trainval.shape)
    print("image_log_trainval.shape",image_log_trainval.shape)
    print("pv_log_trainval.shape",pv_log_trainval.shape)
    print("pv_pred_trainval.shape",pv_pred_trainval.shape)
    
    print("times_test.shape",times_test.shape)
    print("image_log_test.shape",image_log_test.shape)
    print("pv_log_test.shape",pv_log_test.shape)
    print("pv_pred_test.shape",pv_pred_test.shape)
    
    #storing information
    # storing the training set
    np.save(os.path.join(pred_folder,'image_log_trainval.npy'), image_log_trainval)
    np.save(os.path.join(pred_folder,'pv_log_trainval.npy'), pv_log_trainval)
    np.save(os.path.join(pred_folder,'pv_pred_trainval.npy'),pv_pred_trainval)
    np.save(os.path.join(pred_folder,'times_trainval.npy'),times_trainval)

    # storing the testing set
    np.save(os.path.join(pred_folder,'image_log_test.npy'), image_log_test)
    np.save(os.path.join(pred_folder,'pv_log_test.npy'), pv_log_test)
    np.save(os.path.join(pred_folder,'pv_pred_test.npy'),pv_pred_test)
    np.save(os.path.join(pred_folder,'times_test.npy'),times_test)

# %%
# Load in  high frequency data
# The image here are ones that have corresponding PV value
all_times = np.load(os.path.join(data_folder,'all_times_highfreq.npy'), allow_pickle=True)
all_images = np.load(os.path.join(data_folder,'all_images_highfreq.npy'), allow_pickle=True)
pv_data = np.load(pv_data_path, allow_pickle=True)

# only pick out the relevant time period
relevant_mask = (all_times>start_date)&(all_times<end_date)
all_times = all_times[relevant_mask]
all_images = all_images[relevant_mask]
pv_data = pv_data[start_date:end_date]

n_images = all_times.shape[0]

# %%
# Create forecast training data file
for sampling_interval in sampling_interval_all:
    # Initialize variables to save pv values
    image_log = np.zeros([n_images,stack_height+1]+output_img_shape,dtype = 'uint8')
    pv_log = np.zeros((n_images,stack_height+1))
    pv_pred = np.zeros(n_images)
    validity_mask = np.ones(n_images,dtype = bool)
    tic = time.process_time()
    last_valid_index = 0

    sampling_interval_td = datetime.timedelta(minutes = sampling_interval) - datetime.timedelta(seconds=1)
    for i in range(0,n_images):

        # See if the specified sampling frequency is met 
        if all_times[i] - all_times[last_valid_index] > sampling_interval_td:

            # Collecting groud truth for predicted value
            pred_time = all_times[i]+datetime.timedelta(minutes=forecast_horizon)
            
            pv_pred_idx = find_time_within_nparray(pv_data.index,pred_time)
            if pv_pred_idx is None:# if prediction ground truth not found
                validity_mask[i] = False
                print(all_times[i],'has no PV pred')
            else: 
                pv_pred[i] = pv_data.iloc[pv_pred_idx] 

            # Collecting image log and PV log
            for j in range(stack_height+1):
                log_time = all_times[i] - datetime.timedelta(minutes = j)
                # Collecting a stack of image
                log_time_idx = find_time_within_nparray(all_times,log_time)
                if log_time_idx is not None:
                    image_log[i,j] = all_images[log_time_idx]
                else:
                    validity_mask[i] = False
                    print(all_times[i],'has no image log')
                    break

                # Collecting a stack of PV value
                pv_log_idx = find_time_within_nparray(pv_data.index,log_time)
                # Check if PV value present
                if pv_log_idx is None:
                    validity_mask[i] = False
                    print(all_times[i],'has no PV log')
                    break
                else: 
                    pv_log[i,j] = pv_data.iloc[pv_log_idx]    

        else: # if this is in between the sampling points, discard
            validity_mask[i] = False
        
        if validity_mask[i]:
            last_valid_index = i
        
        # Prompt progress of current work
        if i%100 == 0:
            print('processed {0}/{1} images'.format(i,len(all_times)))
            if i%1000 == 0 and i>0:
                print('For sampling frequency: ',sampling_interval,' minutes')
                print('Expected finishing time:', datetime.datetime.now()+
                           datetime.timedelta(seconds = (time.process_time() - tic)*(len(all_times)/i-1)))
    
    # Only pick out the valid time points
    all_times = all_times[validity_mask]
    image_log = image_log[validity_mask]
    pv_log = pv_log[validity_mask]
    pv_pred = pv_pred[validity_mask]
    
    # Store information
    pred_folder_child = os.path.join(pred_folder,'frequency_'+str(sampling_interval))
    store_trainval_test(all_times,image_log,pv_log,pv_pred,pred_folder_child)
# Out:
# processed 0/107992 images
# 2017-03-09 06:49:00 has no image log
# 2017-03-09 06:50:00 has no image log
# 2017-03-09 06:51:00 has no image log
# 2017-03-09 06:52:00 has no image log
# 2017-03-09 06:53:00 has no image log
# 2017-03-09 06:54:00 has no image log
# 2017-03-09 06:55:00 has no image log
# 2017-03-09 06:56:00 has no image log
# 2017-03-09 06:57:00 has no image log
# 2017-03-09 06:58:00 has no image log
# 2017-03-09 06:59:00 has no image log
# 2017-03-09 07:00:00 has no image log
# 2017-03-09 07:01:00 has no image log
# processed 100/107992 images
# 2017-03-09 08:42:30 has no image log
# 2017-03-09 08:43:30 has no image log
# 2017-03-09 08:44:30 has no image log
# 2017-03-09 08:45:30 has no image log
# 2017-03-09 08:46:30 has no image log
# 2017-03-09 08:47:30 has no image log
# 2017-03-09 08:48:30 has no image log
# 2017-03-09 08:49:30 has no image log
# 2017-03-09 08:50:30 has no image log
# 2017-03-09 08:51:30 has no image log
# 2017-03-09 08:52:30 has no image log
# 2017-03-09 08:53:30 has no image log
# 2017-03-09 08:54:30 has no image log
# 2017-03-09 08:55:30 has no image log
# processed 200/107992 images
# processed 300/107992 images
# processed 400/107992 images
# 2017-03-09 13:35:10 has no image log
# 2017-03-09 13:36:10 has no image log
# 2017-03-09 13:37:10 has no image log
# 2017-03-09 13:38:10 has no image log
# 2017-03-09 13:39:10 has no image log
# 2017-03-09 13:40:10 has no image log
# 2017-03-09 13:41:10 has no image log
# 2017-03-09 13:42:10 has no image log
# 2017-03-09 13:43:10 has no image log
# 2017-03-09 13:44:10 has no image log
# 2017-03-09 13:45:10 has no image log
# 2017-03-09 13:46:10 has no image log
# 2017-03-09 13:47:10 has no image log
# 2017-03-09 14:57:00 has no image log
# 2017-03-09 14:58:00 has no image log
# 2017-03-09 14:59:00 has no image log
# 2017-03-09 15:00:00 has no image log
# 2017-03-09 15:01:00 has no image log
# 2017-03-09 15:02:00 has no image log
# 2017-03-09 15:03:00 has no image log
# 2017-03-09 15:04:00 has no image log
# 2017-03-09 15:05:00 has no image log
# 2017-05-15 17:21:30 has no image log
# processed 3800/107992 images
# 2017-05-15 18:41:10 has no image log
# 2017-05-15 18:42:10 has no image log
# 2017-05-15 18:43:10 has no image log
# 2017-05-15 18:44:10 has no image log
# 2017-05-15 18:45:10 has no image log
# 2017-05-15 18:46:10 has no image log
# 2017-05-15 18:47:10 has no image log
# 2017-05-15 18:48:10 has no image log
# 2017-05-15 18:49:10 has no image log
# 2017-05-15 18:50:10 has no image log
# 2017-05-15 18:51:10 has no image log
# 2017-05-15 18:52:10 has no image log
# 2017-05-15 18:53:10 has no image log
# 2017-05-15 18:54:10 has no image log
# 2017-05-15 19:27:10 has no PV pred
# 2017-05-15 19:28:10 has no PV pred
# 2017-05-15 19:29:10 has no PV pred
# 2017-05-15 19:30:10 has no PV pred
# 2017-05-15 19:31:10 has no PV pred
# 2017-05-15 19:32:10 has no PV pred
# 2017-05-15 19:33:10 has no PV pred
# 2017-05-15 19:34:10 has no PV pred
# 2017-05-15 19:35:10 has no PV pred
# 2017-05-15 19:36:10 has no PV pred
# 2017-05-15 19:37:10 has no PV pred
# 2017-05-15 19:38:10 has no PV pred
# 2017-05-15 19:39:10 has no PV pred
# 2017-05-15 19:40:10 has no PV pred
# 2017-05-15 19:41:10 has no PV pred
# processed 3900/107992 images
# 2017-05-16 06:26:00 has no image log
# 2017-05-16 06:27:00 has no image log
# 2017-05-16 06:28:00 has no image log
# 2017-05-16 06:29:00 has no image log
# 2017-05-16 06:30:00 has no image log
# 2017-05-16 06:31:00 has no image log
# 2017-05-16 06:32:00 has no image log
# 2017-05-16 06:33:00 has no image log
# 2017-05-16 06:34:00 has no image log
# 2017-05-16 06:35:00 has no image log
# 2017-05-16 06:36:00 has no image log
# 2017-05-16 06:37:00 has no image log
# 2017-05-16 06:38:00 has no image log
# 2017-05-16 06:39:00 has no image log
# 2017-05-16 06:40:00 has no image log
# 2017-05-16 07:29:10 has no image log
# 2017-05-16 07:30:10 has no image log
# 2017-05-16 07:31:10 has no image log
# 2017-05-16 07:32:10 has no image log
# 2017-05-16 07:33:10 has no image log
# 2017-05-16 07:34:10 has no image log
# 2017-05-16 07:35:10 has no image log
# 2017-05-16 07:36:10 has no image log
# 2017-05-16 07:37:10 has no image log
# 2017-05-16 07:38:10 has no image log
# 2017-05-16 07:39:10 has no image log
# 2017-05-16 07:40:10 has no image log
# 2017-05-16 07:41:10 has no image log
# 2017-05-16 07:42:10 has no image log
# processed 4000/107992 images
# For sampling frequency:  2  minutes
# Expected finishing time: 2022-05-23 22:52:53.275229
# 2017-05-16 08:11:20 has no image log
# 2017-05-16 08:12:20 has no image log
# 2017-05-16 08:13:20 has no image log
# 2017-05-16 08:14:20 has no image log
# 2017-05-16 08:15:20 has no image log
# 2017-05-16 08:16:20 has no image log
# 2017-05-16 08:17:20 has no image log
# 2017-05-16 08:18:20 has no image log
# 2017-05-16 08:19:20 has no image log
# 2017-05-16 08:20:20 has no image log
# 2017-05-16 08:21:20 has no image log
# 2017-05-16 08:22:20 has no image log
# 2017-05-16 08:23:20 has no image log
# 2017-05-16 08:52:40 has no image log
# 2017-05-16 08:53:40 has no image log
# 2017-05-16 08:54:40 has no image log
# 2017-05-16 08:55:40 has no image log
# 2017-05-16 08:56:40 has no image log
# 2017-05-16 08:57:40 has no image log
# 2017-05-16 08:58:40 has no image log
# 2017-05-16 08:59:40 has no image log
# 2017-05-16 09:00:40 has no image log
# 2017-05-16 09:01:40 has no image log
# 2017-05-16 09:02:40 has no image log
# 2017-05-16 09:03:40 has no image log
# 2017-05-16 09:04:40 has no image log
# 2017-05-16 09:38:30 has no image log
# 2017-05-16 09:39:30 has no image log
# 2017-05-16 09:40:30 has no image log
# 2017-05-16 09:41:30 has no image log
# 2017-05-16 09:42:30 has no image log
# processed 4100/107992 images
# 2017-05-16 09:43:30 has no image log
# 2017-05-16 09:44:30 has no image log
# 2017-05-16 09:45:30 has no image log
# 2017-05-16 09:46:30 has no image log
# 2017-05-16 09:47:30 has no image log
# 2017-05-16 09:48:30 has no image log
# 2017-05-16 09:49:30 has no image log
# 2017-05-16 09:50:30 has no image log
# processed 4200/107992 images
# 2017-05-16 12:44:00 has no image log
# 2017-05-16 12:45:00 has no image log
# 2017-05-16 12:46:00 has no image log
# 2017-05-16 12:47:00 has no image log
# 2017-05-16 12:48:00 has no image log
# 2017-05-16 12:49:00 has no image log
# 2017-05-16 12:50:00 has no image log
# 2017-05-16 12:51:00 has no image log
# 2017-05-16 12:52:00 has no image log
# 2017-05-16 12:53:00 has no image log
# 2017-05-16 12:54:00 has no image log
# 2017-05-16 12:55:00 has no image log
# 2017-05-16 12:56:00 has no image log
# 2017-05-16 12:57:00 has no image log
# processed 4300/107992 images
# 2017-05-16 14:24:50 has no image log
# 2017-05-16 14:25:50 has no image log
# 2017-05-16 14:26:50 has no image log
# 2017-05-16 14:27:50 has no image log
# 2017-05-16 14:28:50 has no image log
# 2017-05-16 14:29:50 has no image log
# 2017-05-16 14:30:50 has no image log
# 2017-05-16 14:31:50 has no image log
# 2017-05-16 14:32:50 has no image log
# 2017-05-16 14:33:50 has no image log
# 2017-05-16 14:34:50 has no image log
# 2017-05-16 14:35:50 has no image log
# 2017-05-16 14:36:50 has no image log
# 2017-05-16 14:37:50 has no image log
# processed 4400/107992 images
# 2017-05-16 15:51:40 has no image log
# 2017-05-16 15:52:40 has no image log
# 2017-05-16 15:53:40 has no image log
# 2017-05-16 15:54:40 has no image log
# 2017-05-16 15:55:40 has no image log
# 2017-05-16 15:56:40 has no image log
# 2017-05-16 15:57:40 has no image log
# 2017-05-16 15:58:40 has no image log
# 2017-05-16 15:59:40 has no image log
# 2017-05-16 16:00:40 has no image log
# 2017-05-16 16:01:40 has no image log
# 2017-05-16 16:02:40 has no image log
# 2017-05-16 16:03:40 has no image log
# 2017-05-16 16:04:40 has no image log
# processed 4500/107992 images
# 2017-05-16 17:02:10 has no image log
# 2017-05-16 17:03:10 has no image log
# 2017-05-16 17:04:10 has no image log
# 2017-05-16 17:05:10 has no image log
# 2017-05-16 17:06:10 has no image log
# 2017-05-16 17:07:10 has no image log
# 2017-05-16 17:08:10 has no image log
# 2017-05-16 17:09:10 has no image log
# 2017-05-16 17:10:10 has no image log
# 2017-05-16 17:11:10 has no image log
# 2017-05-16 17:12:10 has no image log
# 2017-05-16 17:13:10 has no image log
# 2017-05-16 17:14:10 has no image log
# 2017-05-16 17:15:10 has no image log
# processed 4600/107992 images
# 2017-05-16 19:30:10 has no PV pred
# 2017-05-16 19:31:10 has no PV pred
# 2017-05-16 19:32:10 has no PV pred
# 2017-05-16 19:33:10 has no PV pred
# 2017-05-16 19:34:10 has no PV pred
# 2017-05-16 19:35:10 has no PV pred
# 2017-05-16 19:36:10 has no PV pred
# 2017-05-16 19:37:10 has no PV pred
# 2017-05-16 19:38:10 has no PV pred
# 2017-05-16 19:39:10 has no PV pred
# 2017-05-16 19:40:10 has no PV pred
# 2017-05-16 19:41:10 has no PV pred
# processed 4700/107992 images
# 2017-05-16 19:42:10 has no PV pred
# 2017-05-16 19:43:10 has no PV pred
# 2017-05-16 19:44:10 has no PV pred
# 2017-05-18 15:54:50 has no image log
# 2017-05-18 15:55:50 has no image log
# 2017-05-18 15:56:50 has no image log
# 2017-05-18 15:57:50 has no image log
# 2017-05-18 15:58:50 has no image log
# 2017-05-18 15:59:50 has no image log
# 2017-05-18 16:00:50 has no image log
# 2017-05-18 16:01:50 has no image log
# 2017-05-18 16:02:50 has no image log
# 2017-05-18 16:03:50 has no image log
# 2017-05-18 16:04:50 has no image log
# 2017-05-18 16:05:50 has no image log
# 2017-05-18 16:06:50 has no image log
# 2017-05-18 16:07:50 has no image log
# 2017-05-18 16:08:50 has no image log
# 2017-05-18 17:20:30 has no image log
# 2017-05-18 17:21:30 has no image log
# 2017-05-18 17:22:30 has no image log
# 2017-05-18 17:23:30 has no image log
# 2017-05-18 17:24:30 has no image log
# 2017-05-18 17:25:30 has no image log
# 2017-05-18 17:26:30 has no image log
# 2017-05-18 17:27:30 has no image log
# 2017-05-18 17:28:30 has no image log
# 2017-05-18 17:29:30 has no image log
# 2017-05-18 17:30:30 has no image log
# processed 4800/107992 images
# 2017-05-18 17:31:30 has no image log
# 2017-05-18 17:32:30 has no image log
# processed 4900/107992 images
# 2017-05-18 19:33:30 has no PV pred
# 2017-05-18 19:34:30 has no PV pred
# 2017-05-18 19:35:30 has no PV pred
# 2017-05-18 19:36:30 has no PV pred
# 2017-05-18 19:37:30 has no PV pred
# 2017-05-18 19:38:30 has no PV pred
# 2017-05-18 19:39:30 has no PV pred
# 2017-05-18 19:40:30 has no PV pred
# 2017-05-18 19:41:30 has no PV pred
# 2017-05-18 19:42:30 has no PV pred
# 2017-05-18 19:43:30 has no PV pred
# 2017-05-18 19:44:30 has no PV pred
# 2017-05-18 19:45:30 has no PV pred
# 2017-05-18 19:46:30 has no PV pred
# 2017-05-18 19:47:30 has no PV pred
# 2017-05-19 06:21:00 has no image log
# 2017-05-19 06:22:00 has no image log
# 2017-05-19 06:23:00 has no image log
# 2017-05-19 06:24:00 has no image log
# 2017-05-19 06:25:00 has no image log
# 2017-05-19 06:26:00 has no image log
# 2017-05-19 06:27:00 has no image log
# 2017-05-19 06:28:00 has no image log
# 2017-05-19 06:29:00 has no image log
# 2017-05-19 06:30:00 has no image log
# 2017-05-19 06:31:00 has no image log
# 2017-05-19 06:32:00 has no image log
# 2017-05-19 06:33:00 has no image log
# 2017-05-19 06:34:00 has no image log
# 2017-05-19 06:35:00 has no image log
# processed 5000/107992 images
# For sampling frequency:  2  minutes
# Expected finishing time: 2022-05-23 22:52:51.441014
# 2017-05-19 07:42:10 has no image log
# 2017-05-19 07:43:10 has no image log
# 2017-05-19 07:44:10 has no image log
# 2017-05-19 07:45:10 has no image log
# 2017-05-19 07:46:10 has no image log
# 2017-05-19 07:47:10 has no image log
# ...
# 2017-10-31 17:21:00 has no image log
# 2017-10-31 17:22:00 has no image log
# 2017-10-31 17:23:00 has no image log
# 2017-10-31 17:24:00 has no image log
# 2017-10-31 17:25:00 has no image log
# 2017-10-31 17:26:00 has no image log
# 2017-10-31 17:27:00 has no image log
# 2017-10-31 17:28:00 has no image log
# 2017-10-31 17:29:00 has no image log
# 2017-10-31 17:30:00 has no image log
# 2017-10-31 17:31:00 has no image log
# 2017-10-31 17:32:00 has no image log
# 2017-10-31 17:33:00 has no image log
# 2017-10-31 17:34:00 has no image log
# 2017-10-31 17:35:00 has no image log
# processed 103500/107992 images
# 2017-10-31 17:42:00 has no PV pred
# 2017-10-31 17:43:00 has no PV pred
# 2017-10-31 17:44:00 has no PV pred
# 2017-10-31 17:45:00 has no PV pred
# 2017-10-31 17:46:00 has no PV pred
# 2017-10-31 17:47:00 has no PV pred
# 2017-10-31 17:48:00 has no PV pred
# 2017-10-31 17:49:00 has no PV pred
# 2017-10-31 17:50:00 has no PV pred
# 2017-10-31 17:51:00 has no PV pred
# 2017-10-31 17:52:00 has no PV pred
# 2017-10-31 17:53:00 has no PV pred
# 2017-10-31 17:54:00 has no PV pred
# 2017-10-31 17:55:00 has no PV pred
# 2017-11-01 07:51:00 has no image log
# 2017-11-01 07:52:00 has no image log
# 2017-11-01 07:53:00 has no image log
# 2017-11-01 07:54:00 has no image log
# 2017-11-01 07:55:00 has no image log
# 2017-11-01 07:56:00 has no image log
# 2017-11-01 07:57:00 has no image log
# 2017-11-01 07:58:00 has no image log
# 2017-11-01 07:59:00 has no image log
# 2017-11-01 08:00:00 has no image log
# 2017-11-01 08:01:00 has no image log
# 2017-11-01 08:02:00 has no image log
# 2017-11-01 08:03:00 has no image log
# 2017-11-01 08:04:00 has no image log
# 2017-11-01 08:05:00 has no image log
# processed 103600/107992 images
# processed 103700/107992 images
# processed 103800/107992 images
# processed 103900/107992 images
# processed 104000/107992 images
# For sampling frequency:  2  minutes
# Expected finishing time: 2022-05-23 22:52:47.246387
# processed 104100/107992 images
# 2017-11-01 17:38:00 has no PV pred
# 2017-11-01 17:39:00 has no PV pred
# 2017-11-01 17:40:00 has no PV pred
# 2017-11-01 17:41:00 has no PV pred
# 2017-11-01 17:42:00 has no PV pred
# 2017-11-01 17:43:00 has no PV pred
# 2017-11-01 17:44:00 has no PV pred
# 2017-11-01 17:45:00 has no PV pred
# 2017-11-01 17:46:00 has no PV pred
# 2017-11-01 17:47:00 has no PV pred
# 2017-11-01 17:48:00 has no PV pred
# 2017-11-01 17:49:00 has no PV pred
# 2017-11-01 17:50:00 has no PV pred
# 2017-11-01 17:51:00 has no PV pred
# 2017-11-02 07:54:00 has no image log
# 2017-11-02 08:46:00 has no image log
# 2017-11-02 08:47:00 has no image log
# 2017-11-02 08:48:00 has no image log
# 2017-11-02 08:49:00 has no image log
# 2017-11-02 08:50:00 has no image log
# 2017-11-02 08:51:00 has no image log
# 2017-11-02 08:52:00 has no image log
# 2017-11-02 08:53:00 has no image log
# 2017-11-02 08:54:00 has no image log
# 2017-11-02 08:55:00 has no image log
# 2017-11-02 08:56:00 has no image log
# 2017-11-02 08:57:00 has no image log
# 2017-11-02 08:58:00 has no image log
# 2017-11-02 08:59:00 has no image log
# 2017-11-02 09:00:00 has no image log
# processed 104200/107992 images
# processed 104300/107992 images
# processed 104400/107992 images
# processed 104500/107992 images
# processed 104600/107992 images
# 2017-11-02 17:35:00 has no PV pred
# 2017-11-02 17:36:00 has no PV pred
# 2017-11-02 17:37:00 has no PV pred
# 2017-11-02 17:38:00 has no PV pred
# 2017-11-02 17:39:00 has no PV pred
# 2017-11-02 17:40:00 has no PV pred
# 2017-11-02 17:41:00 has no PV pred
# 2017-11-02 17:42:00 has no PV pred
# 2017-11-02 17:43:00 has no PV pred
# 2017-11-02 17:44:00 has no PV pred
# 2017-11-02 17:45:00 has no PV pred
# 2017-11-02 17:46:00 has no PV pred
# 2017-11-02 17:47:00 has no PV pred
# 2017-11-02 17:48:00 has no PV pred
# 2017-11-03 08:02:00 has no image log
# 2017-11-03 08:03:00 has no image log
# 2017-11-03 08:04:00 has no image log
# 2017-11-03 08:05:00 has no image log
# 2017-11-03 08:06:00 has no image log
# 2017-11-03 08:07:00 has no image log
# 2017-11-03 08:08:00 has no image log
# 2017-11-03 08:09:00 has no image log
# 2017-11-03 08:10:00 has no image log
# 2017-11-03 08:11:00 has no image log
# 2017-11-03 08:12:00 has no image log
# 2017-11-03 08:13:00 has no image log
# 2017-11-03 08:14:00 has no image log
# 2017-11-03 08:15:00 has no image log
# 2017-11-03 08:16:00 has no image log
# processed 104700/107992 images
# 2017-11-03 10:52:00 has no image log
# 2017-11-03 10:53:00 has no image log
# 2017-11-03 10:54:00 has no image log
# 2017-11-03 10:55:00 has no image log
# processed 104800/107992 images
# 2017-11-03 10:56:00 has no image log
# 2017-11-03 10:57:00 has no image log
# 2017-11-03 10:58:00 has no image log
# 2017-11-03 10:59:00 has no image log
# 2017-11-03 11:00:00 has no image log
# 2017-11-03 11:01:00 has no image log
# 2017-11-03 11:02:00 has no image log
# 2017-11-03 11:03:00 has no image log
# 2017-11-03 11:04:00 has no image log
# 2017-11-03 11:05:00 has no image log
# 2017-11-03 11:06:00 has no image log
# processed 104900/107992 images
# processed 105000/107992 images
# For sampling frequency:  2  minutes
# Expected finishing time: 2022-05-23 22:52:47.339170
# processed 105100/107992 images
# 2017-11-03 16:45:00 has no PV pred
# 2017-11-03 16:46:00 has no PV pred
# 2017-11-03 16:47:00 has no PV pred
# 2017-11-03 16:48:00 has no PV pred
# 2017-11-03 16:49:00 has no PV pred
# 2017-11-03 16:50:00 has no PV pred
# 2017-11-03 16:51:00 has no PV pred
# 2017-11-03 16:52:00 has no PV pred
# 2017-11-03 16:53:00 has no PV pred
# 2017-11-03 16:54:00 has no PV pred
# 2017-11-03 16:55:00 has no PV pred
# 2017-11-03 16:56:00 has no PV pred
# 2017-11-03 16:57:00 has no PV pred
# 2017-11-03 16:58:00 has no PV pred
# 2017-11-03 16:59:00 has no PV pred
# 2017-11-04 08:18:00 has no image log
# 2017-11-04 08:19:00 has no image log
# 2017-11-04 08:20:00 has no image log
# 2017-11-04 08:21:00 has no image log
# 2017-11-04 08:22:00 has no image log
# 2017-11-04 08:23:00 has no image log
# 2017-11-04 08:24:00 has no image log
# 2017-11-04 08:25:00 has no image log
# 2017-11-04 08:26:00 has no image log
# 2017-11-04 08:27:00 has no image log
# 2017-11-04 08:28:00 has no image log
# 2017-11-04 08:29:00 has no image log
# 2017-11-04 08:30:00 has no image log
# 2017-11-04 08:31:00 has no image log
# 2017-11-04 08:32:00 has no image log
# processed 105200/107992 images
# processed 105300/107992 images
# processed 105400/107992 images
# 2017-11-04 13:05:00 has no image log
# 2017-11-04 13:06:00 has no image log
# 2017-11-04 13:07:00 has no image log
# 2017-11-04 13:08:00 has no image log
# 2017-11-04 13:09:00 has no image log
# 2017-11-04 13:10:00 has no image log
# 2017-11-04 13:11:00 has no image log
# 2017-11-04 13:12:00 has no image log
# 2017-11-04 13:13:00 has no image log
# 2017-11-04 13:14:00 has no image log
# 2017-11-04 13:15:00 has no image log
# 2017-11-04 13:16:00 has no image log
# 2017-11-04 13:17:00 has no image log
# 2017-11-04 13:18:00 has no image log
# 2017-11-04 13:19:00 has no image log
# processed 105500/107992 images
# processed 105600/107992 images
# 2017-11-04 17:28:00 has no PV pred
# 2017-11-04 17:29:00 has no PV pred
# processed 105700/107992 images
# 2017-11-04 17:30:00 has no PV pred
# 2017-11-04 17:31:00 has no PV pred
# 2017-11-04 17:32:00 has no PV pred
# 2017-11-04 17:33:00 has no PV pred
# 2017-11-04 17:34:00 has no PV pred
# 2017-11-04 17:35:00 has no PV pred
# 2017-11-04 17:36:00 has no PV pred
# 2017-11-04 17:37:00 has no PV pred
# 2017-11-04 17:38:00 has no PV pred
# 2017-11-04 17:39:00 has no PV pred
# 2017-11-04 17:40:00 has no PV pred
# 2017-11-04 17:41:00 has no PV pred
# 2017-11-04 17:42:00 has no PV pred
# 2017-12-25 11:37:00 has no image log
# 2017-12-25 11:38:00 has no image log
# 2017-12-25 11:39:00 has no image log
# 2017-12-25 11:40:00 has no image log
# 2017-12-25 11:41:00 has no image log
# 2017-12-25 11:42:00 has no image log
# 2017-12-25 11:43:00 has no image log
# 2017-12-25 11:44:00 has no image log
# 2017-12-25 11:45:00 has no image log
# 2017-12-25 11:46:00 has no image log
# 2017-12-25 11:47:00 has no image log
# 2017-12-25 11:48:00 has no image log
# 2017-12-25 11:49:00 has no image log
# 2017-12-25 11:50:00 has no image log
# 2017-12-25 11:51:00 has no image log
# processed 105800/107992 images
# processed 105900/107992 images
# 2017-12-25 16:16:00 has no PV pred
# 2017-12-25 16:17:00 has no PV pred
# 2017-12-25 16:18:00 has no PV pred
# 2017-12-25 16:19:00 has no PV pred
# 2017-12-25 16:20:00 has no PV pred
# 2017-12-25 16:21:00 has no PV pred
# 2017-12-25 16:22:00 has no PV pred
# 2017-12-25 16:23:00 has no PV pred
# processed 106000/107992 images
# For sampling frequency:  2  minutes
# Expected finishing time: 2022-05-23 22:52:47.388357
# 2017-12-25 16:24:00 has no PV pred
# 2017-12-25 16:25:00 has no PV pred
# 2017-12-25 16:26:00 has no PV pred
# 2017-12-25 16:27:00 has no PV pred
# 2017-12-25 16:28:00 has no PV pred
# 2017-12-25 16:29:00 has no PV pred
# 2017-12-26 07:33:00 has no image log
# 2017-12-26 08:47:00 has no image log
# 2017-12-26 08:48:00 has no image log
# 2017-12-26 08:49:00 has no image log
# 2017-12-26 08:50:00 has no image log
# 2017-12-26 08:51:00 has no image log
# 2017-12-26 08:52:00 has no image log
# 2017-12-26 08:53:00 has no image log
# 2017-12-26 08:54:00 has no image log
# 2017-12-26 08:55:00 has no image log
# 2017-12-26 08:56:00 has no image log
# 2017-12-26 08:57:00 has no image log
# 2017-12-26 08:58:00 has no image log
# 2017-12-26 08:59:00 has no image log
# 2017-12-26 09:00:00 has no image log
# 2017-12-26 09:01:00 has no image log
# processed 106100/107992 images
# processed 106200/107992 images
# processed 106300/107992 images
# processed 106400/107992 images
# 2017-12-26 16:30:00 has no PV pred
# 2017-12-26 16:31:00 has no PV pred
# 2017-12-26 16:32:00 has no PV pred
# 2017-12-26 16:33:00 has no PV pred
# 2017-12-26 16:34:00 has no PV pred
# 2017-12-26 16:35:00 has no PV pred
# 2017-12-26 16:36:00 has no PV pred
# 2017-12-26 16:37:00 has no PV pred
# 2017-12-26 16:38:00 has no PV pred
# 2017-12-26 16:39:00 has no PV pred
# 2017-12-26 16:40:00 has no PV pred
# 2017-12-26 16:41:00 has no PV pred
# 2017-12-26 16:42:00 has no PV pred
# 2017-12-26 16:43:00 has no PV pred
# 2017-12-27 07:36:00 has no image log
# 2017-12-27 07:37:00 has no image log
# 2017-12-27 07:38:00 has no image log
# 2017-12-27 07:39:00 has no image log
# 2017-12-27 07:40:00 has no image log
# 2017-12-27 07:41:00 has no image log
# 2017-12-27 07:42:00 has no image log
# 2017-12-27 07:43:00 has no image log
# 2017-12-27 07:44:00 has no image log
# 2017-12-27 07:45:00 has no image log
# 2017-12-27 07:46:00 has no image log
# 2017-12-27 07:47:00 has no image log
# 2017-12-27 07:48:00 has no image log
# 2017-12-27 07:49:00 has no image log
# 2017-12-27 07:50:00 has no image log
# processed 106500/107992 images
# processed 106600/107992 images
# 2017-12-27 10:26:00 has no image log
# 2017-12-27 10:27:00 has no image log
# 2017-12-27 10:28:00 has no image log
# 2017-12-27 10:29:00 has no image log
# 2017-12-27 10:30:00 has no image log
# 2017-12-27 10:31:00 has no image log
# 2017-12-27 10:32:00 has no image log
# 2017-12-27 10:33:00 has no image log
# 2017-12-27 10:34:00 has no image log
# 2017-12-27 10:35:00 has no image log
# 2017-12-27 10:36:00 has no image log
# 2017-12-27 10:37:00 has no image log
# 2017-12-27 10:38:00 has no image log
# 2017-12-27 10:39:00 has no image log
# 2017-12-27 10:40:00 has no image log
# processed 106700/107992 images
# processed 106800/107992 images
# processed 106900/107992 images
# 2017-12-27 16:29:00 has no PV pred
# 2017-12-27 16:30:00 has no PV pred
# 2017-12-27 16:31:00 has no PV pred
# 2017-12-27 16:32:00 has no PV pred
# 2017-12-27 16:33:00 has no PV pred
# 2017-12-27 16:34:00 has no PV pred
# 2017-12-27 16:35:00 has no PV pred
# 2017-12-27 16:36:00 has no PV pred
# 2017-12-27 16:37:00 has no PV pred
# 2017-12-27 16:38:00 has no PV pred
# 2017-12-27 16:39:00 has no PV pred
# 2017-12-27 16:40:00 has no PV pred
# 2017-12-27 16:41:00 has no PV pred
# 2017-12-27 16:42:00 has no PV pred
# 2017-12-27 16:43:00 has no PV pred
# processed 107000/107992 images
# For sampling frequency:  2  minutes
# Expected finishing time: 2022-05-23 22:52:47.491302
# 2017-12-28 07:47:00 has no image log
# 2017-12-28 07:48:00 has no image log
# 2017-12-28 07:49:00 has no image log
# 2017-12-28 07:50:00 has no image log
# 2017-12-28 07:51:00 has no image log
# 2017-12-28 07:52:00 has no image log
# 2017-12-28 07:53:00 has no image log
# 2017-12-28 07:54:00 has no image log
# 2017-12-28 07:55:00 has no image log
# 2017-12-28 07:56:00 has no image log
# 2017-12-28 07:57:00 has no image log
# 2017-12-28 07:58:00 has no image log
# 2017-12-28 07:59:00 has no image log
# 2017-12-28 08:00:00 has no image log
# 2017-12-28 08:01:00 has no image log
# processed 107100/107992 images
# processed 107200/107992 images
# 2017-12-28 12:58:00 has no image log
# 2017-12-28 12:59:00 has no image log
# 2017-12-28 13:00:00 has no image log
# 2017-12-28 13:01:00 has no image log
# 2017-12-28 13:02:00 has no image log
# 2017-12-28 13:03:00 has no image log
# 2017-12-28 13:04:00 has no image log
# 2017-12-28 13:05:00 has no image log
# 2017-12-28 13:06:00 has no image log
# 2017-12-28 13:07:00 has no image log
# 2017-12-28 13:08:00 has no image log
# 2017-12-28 13:09:00 has no image log
# 2017-12-28 13:10:00 has no image log
# 2017-12-28 13:11:00 has no image log
# 2017-12-28 13:12:00 has no image log
# processed 107300/107992 images
# processed 107400/107992 images
# 2017-12-28 16:31:00 has no PV pred
# 2017-12-28 16:32:00 has no PV pred
# 2017-12-28 16:33:00 has no PV pred
# 2017-12-28 16:34:00 has no PV pred
# 2017-12-28 16:35:00 has no PV pred
# 2017-12-28 16:36:00 has no PV pred
# 2017-12-28 16:37:00 has no PV pred
# 2017-12-28 16:38:00 has no PV pred
# 2017-12-28 16:39:00 has no PV pred
# processed 107500/107992 images
# 2017-12-28 16:40:00 has no PV pred
# 2017-12-28 16:41:00 has no PV pred
# 2017-12-28 16:42:00 has no PV pred
# 2017-12-28 16:43:00 has no PV pred
# 2017-12-28 16:44:00 has no PV pred
# 2017-12-29 07:36:00 has no image log
# 2017-12-29 07:37:00 has no image log
# 2017-12-29 07:38:00 has no image log
# 2017-12-29 07:39:00 has no image log
# 2017-12-29 07:40:00 has no image log
# 2017-12-29 07:41:00 has no image log
# 2017-12-29 07:42:00 has no image log
# 2017-12-29 07:43:00 has no image log
# 2017-12-29 07:44:00 has no image log
# 2017-12-29 07:45:00 has no image log
# 2017-12-29 07:46:00 has no image log
# 2017-12-29 07:47:00 has no image log
# 2017-12-29 07:48:00 has no image log
# 2017-12-29 07:49:00 has no image log
# 2017-12-29 07:50:00 has no image log
# processed 107600/107992 images
# processed 107700/107992 images
# 2017-12-29 12:15:00 has no image log
# 2017-12-29 12:16:00 has no image log
# 2017-12-29 12:17:00 has no image log
# 2017-12-29 12:18:00 has no image log
# 2017-12-29 12:19:00 has no image log
# 2017-12-29 12:20:00 has no image log
# 2017-12-29 12:21:00 has no image log
# 2017-12-29 12:22:00 has no image log
# 2017-12-29 12:23:00 has no image log
# 2017-12-29 12:24:00 has no image log
# 2017-12-29 12:25:00 has no image log
# 2017-12-29 12:26:00 has no image log
# 2017-12-29 12:27:00 has no image log
# 2017-12-29 12:28:00 has no image log
# 2017-12-29 12:29:00 has no image log
# processed 107800/107992 images
# processed 107900/107992 images
# 2017-12-29 15:52:00 has no image log
# 2017-12-29 15:53:00 has no image log
# 2017-12-29 15:54:00 has no image log
# 2017-12-29 15:55:00 has no image log
# 2017-12-29 15:56:00 has no image log
# 2017-12-29 15:57:00 has no image log
# 2017-12-29 15:58:00 has no image log
# 2017-12-29 15:59:00 has no image log
# 2017-12-29 16:00:00 has no image log
# 2017-12-29 16:01:00 has no image log
# 2017-12-29 16:02:00 has no image log
# 2017-12-29 16:03:00 has no image log
# 2017-12-29 16:04:00 has no image log
# 2017-12-29 16:05:00 has no image log
# 2017-12-29 16:06:00 has no image log
# 2017-12-29 16:25:00 has no PV pred
# 2017-12-29 16:26:00 has no PV pred
# 2017-12-29 16:27:00 has no PV pred
# 2017-12-29 16:28:00 has no PV pred
# 2017-12-29 16:29:00 has no PV pred
# 2017-12-29 16:30:00 has no PV pred
# 2017-12-29 16:31:00 has no PV pred
# 2017-12-29 16:32:00 has no PV pred
# 2017-12-29 16:33:00 has no PV pred
# 2017-12-29 16:34:00 has no PV pred
# 2017-12-29 16:35:00 has no PV pred
# 2017-12-29 16:36:00 has no PV pred
# 2017-12-29 16:37:00 has no PV pred
# 2017-12-29 16:38:00 has no PV pred
# times_trainval.shape (42881,)
# image_log_trainval.shape (42881, 16, 64, 64, 3)
# pv_log_trainval.shape (42881, 16)
# pv_pred_trainval.shape (42881,)
# times_test.shape (3830,)
# image_log_test.shape (3830, 16, 64, 64, 3)
# pv_log_test.shape (3830, 16)
# pv_pred_test.shape (3830,)
