# %%
# import packages 

import numpy as np
import os
import datetime
import time
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline


# folder path and name
project_path = os.getcwd()
data_folder = os.path.join(project_path,"data_expanded")
pred_folder = os.path.join(data_folder,'data_forecast')
pv_data_path = os.path.join(project_path,'pv_data','pv_output_valid.pkl')

image_name_format = '%Y%m%d%H%M%S'

# Operating parameter
stack_height = 15 # 15 minute
forecast_horizon = 15 # 15 minutes ahead forecast
sampling_interval_all = [2]
output_img_shape = [64, 64, 3]

start_date = datetime.datetime(2017,3,9)
end_date = datetime.datetime(2017,12,31)

# Setting up test set
sunny_day = [(2017,5,12)]
cloudy_day = [(2017,5,13)]

sunny_datetime = [datetime.datetime(day[0],day[1],day[2]) for day in sunny_day]
cloudy_datetime = [datetime.datetime(day[0],day[1],day[2]) for day in cloudy_day]
test_dates = sunny_datetime + cloudy_datetime

# %%
def find_idx_with_dates(all_times,test_dates):
    idx=[]
    for test_day in test_dates:
        test_day_end = test_day + datetime.timedelta(days = 1)
        idx+=np.nonzero((all_times>test_day)*(all_times<test_day_end))[0].tolist()
    return idx

# This two function does the same thing. Just that one is for np, the other for pd.

def find_time_within_nparray(time_array,time_point):
    probable_idx = np.searchsorted(time_array,time_point)
    
    # If the time point is after all the time in pv_data
    if probable_idx == len(time_array):
        return None   
    
    # See if the time point is actually a match 
    if time_array[probable_idx]== time_point: 
        return probable_idx
        
    else:
        return None

def find_time_within_pdseries(time_array,time_point):
    probable_idx = np.searchsorted(time_array,time_point)
    
    # If the time point is after all the time in pv_data
    if probable_idx == len(time_array):
        return None   
    
    # See if the time point is actually a match 
    if time_array[probable_idx] == time_point: 
        return probable_idx
        
    else:
        return None

# %%
def store_trainval_test(all_times,image_log,pv_log,pv_pred,pred_folder):
    
    ## Splitting into Trainval and Test set 
    idx_test = find_idx_with_dates(all_times,test_dates)
    image_log_test = image_log[idx_test]
    pv_log_test = pv_log[idx_test]
    pv_pred_test = pv_pred[idx_test]
    times_test = all_times[idx_test]

    # the rest become the trainval set
    mask_trainval = np.ones_like(pv_pred,dtype = bool)
    mask_trainval[idx_test] = 0
    image_log_trainval = image_log[mask_trainval]
    pv_log_trainval = pv_log[mask_trainval]
    pv_pred_trainval = pv_pred[mask_trainval]
    times_trainval = all_times[mask_trainval]
    
    print("times_trainval.shape",times_trainval.shape)
    print("image_log_trainval.shape",image_log_trainval.shape)
    print("pv_log_trainval.shape",pv_log_trainval.shape)
    print("pv_pred_trainval.shape",pv_pred_trainval.shape)
    
    print("times_test.shape",times_test.shape)
    print("image_log_test.shape",image_log_test.shape)
    print("pv_log_test.shape",pv_log_test.shape)
    print("pv_pred_test.shape",pv_pred_test.shape)
    
    #storing information
    # storing the training set
    np.save(os.path.join(pred_folder,'image_log_trainval.npy'), image_log_trainval)
    np.save(os.path.join(pred_folder,'pv_log_trainval.npy'), pv_log_trainval)
    np.save(os.path.join(pred_folder,'pv_pred_trainval.npy'),pv_pred_trainval)
    np.save(os.path.join(pred_folder,'times_trainval.npy'),times_trainval)

    # storing the testing set
    np.save(os.path.join(pred_folder,'image_log_test.npy'), image_log_test)
    np.save(os.path.join(pred_folder,'pv_log_test.npy'), pv_log_test)
    np.save(os.path.join(pred_folder,'pv_pred_test.npy'),pv_pred_test)
    np.save(os.path.join(pred_folder,'times_test.npy'),times_test)

# %%
# Load in  high frequency data
# The image here are ones that have corresponding PV value
all_times = np.load(os.path.join(data_folder,'all_times_highfreq.npy'), allow_pickle=True)
all_images = np.load(os.path.join(data_folder,'all_images_highfreq.npy'), allow_pickle=True)
pv_data = np.load(pv_data_path, allow_pickle=True)

# only pick out the relevant time period
relevant_mask = (all_times>start_date)&(all_times<end_date)
all_times = all_times[relevant_mask]
all_images = all_images[relevant_mask]
pv_data = pv_data[start_date:end_date]

n_images = all_times.shape[0]

# %%
# Create forecast training data file
for sampling_interval in sampling_interval_all:
    # Initialize variables to save pv values
    image_log = np.zeros([n_images,stack_height+1]+output_img_shape,dtype = 'uint8')
    pv_log = np.zeros((n_images,stack_height+1))
    pv_pred = np.zeros(n_images)
    validity_mask = np.ones(n_images,dtype = bool)
    tic = time.process_time()
    last_valid_index = 0

    sampling_interval_td = datetime.timedelta(minutes = sampling_interval) - datetime.timedelta(seconds=1)
    for i in range(0,n_images):

        # See if the specified sampling frequency is met 
        if all_times[i] - all_times[last_valid_index] > sampling_interval_td:

            # Collecting groud truth for predicted value
            pred_time = all_times[i]+datetime.timedelta(minutes=forecast_horizon)
            
            pv_pred_idx = find_time_within_nparray(pv_data.index,pred_time)
            if pv_pred_idx is None:# if prediction ground truth not found
                validity_mask[i] = False
                print(all_times[i],'has no PV pred')
            else: 
                pv_pred[i] = pv_data.iloc[pv_pred_idx] 

            # Collecting image log and PV log
            for j in range(stack_height+1):
                log_time = all_times[i] - datetime.timedelta(minutes = j)
                # Collecting a stack of image
                log_time_idx = find_time_within_nparray(all_times,log_time)
                if log_time_idx is not None:
                    image_log[i,j] = all_images[log_time_idx]
                else:
                    validity_mask[i] = False
                    print(all_times[i],'has no image log')
                    break

                # Collecting a stack of PV value
                pv_log_idx = find_time_within_nparray(pv_data.index,log_time)
                # Check if PV value present
                if pv_log_idx is None:
                    validity_mask[i] = False
                    print(all_times[i],'has no PV log')
                    break
                else: 
                    pv_log[i,j] = pv_data.iloc[pv_log_idx]    

        else: # if this is in between the sampling points, discard
            validity_mask[i] = False
        
        if validity_mask[i]:
            last_valid_index = i
        
        # Prompt progress of current work
        if i%100 == 0:
            print('processed {0}/{1} images'.format(i,len(all_times)))
            if i%1000 == 0 and i>0:
                print('For sampling frequency: ',sampling_interval,' minutes')
                print('Expected finishing time:', datetime.datetime.now()+
                           datetime.timedelta(seconds = (time.process_time() - tic)*(len(all_times)/i-1)))
    
    # Only pick out the valid time points
    all_times = all_times[validity_mask]
    image_log = image_log[validity_mask]
    pv_log = pv_log[validity_mask]
    pv_pred = pv_pred[validity_mask]
    
    # Store information
    pred_folder_child = os.path.join(pred_folder,'frequency_'+str(sampling_interval))
    store_trainval_test(all_times,image_log,pv_log,pv_pred,pred_folder_child)
# Out:
# processed 0/7163 images
# 2017-05-14 06:05:00 has no image log
# 2017-05-14 06:10:00 has no image log
# 2017-05-14 06:15:00 has no image log
# 2017-05-14 06:20:00 has no image log
# 2017-05-14 06:25:00 has no image log
# 2017-05-14 06:30:00 has no image log
# 2017-05-14 06:35:00 has no image log
# 2017-05-14 06:40:00 has no image log
# 2017-05-14 06:45:00 has no image log
# 2017-05-14 06:50:00 has no image log
# 2017-05-14 06:55:00 has no image log
# 2017-05-14 07:00:00 has no image log
# 2017-05-14 07:05:00 has no image log
# 2017-05-14 07:10:00 has no image log
# 2017-05-14 07:15:00 has no image log
# 2017-05-14 07:20:00 has no image log
# 2017-05-14 07:25:00 has no image log
# 2017-05-14 07:30:00 has no image log
# 2017-05-14 07:35:00 has no image log
# 2017-05-14 07:40:00 has no image log
# 2017-05-14 07:45:00 has no image log
# 2017-05-14 07:50:00 has no image log
# 2017-05-14 07:55:00 has no image log
# 2017-05-14 08:00:00 has no image log
# 2017-05-14 08:05:00 has no image log
# 2017-05-14 08:10:00 has no image log
# 2017-05-14 08:15:00 has no image log
# 2017-05-14 08:20:00 has no image log
# 2017-05-14 08:25:00 has no image log
# 2017-05-14 08:30:00 has no image log
# 2017-05-14 08:35:00 has no image log
# 2017-05-14 08:40:00 has no image log
# 2017-05-14 08:45:00 has no image log
# 2017-05-14 08:50:00 has no image log
# 2017-05-14 08:55:00 has no image log
# 2017-05-14 09:00:00 has no image log
# 2017-05-14 09:05:00 has no image log
# 2017-05-14 09:10:00 has no image log
# 2017-05-14 09:15:00 has no image log
# 2017-05-14 09:20:00 has no image log
# 2017-05-14 09:25:00 has no image log
# 2017-05-14 09:30:00 has no image log
# 2017-05-14 09:35:00 has no image log
# 2017-05-14 09:40:00 has no image log
# 2017-05-14 09:45:00 has no image log
# 2017-05-14 09:50:00 has no image log
# 2017-05-14 09:55:00 has no image log
# 2017-05-14 10:00:00 has no image log
# 2017-05-14 10:05:00 has no image log
# 2017-05-14 11:23:20 has no image log
# 2017-05-14 11:28:20 has no image log
# 2017-05-14 11:33:20 has no image log
# 2017-05-14 11:38:20 has no image log
# 2017-05-14 11:43:20 has no image log
# 2017-05-14 11:48:20 has no image log
# 2017-05-14 11:53:20 has no image log
# 2017-05-14 11:58:20 has no image log
# 2017-05-14 12:03:20 has no image log
# 2017-05-14 12:08:20 has no image log
# 2017-05-14 12:13:20 has no image log
# 2017-05-14 12:18:20 has no image log
# 2017-05-14 12:23:20 has no image log
# 2017-05-14 12:28:20 has no image log
# 2017-05-14 12:33:20 has no image log
# 2017-05-14 12:38:20 has no image log
# 2017-05-14 12:43:20 has no image log
# 2017-05-14 12:46:40 has no image log
# 2017-05-14 12:51:40 has no image log
# 2017-05-14 12:56:40 has no image log
# 2017-05-14 13:01:40 has no image log
# 2017-05-14 13:06:40 has no image log
# 2017-05-14 13:11:40 has no image log
# 2017-05-14 13:16:40 has no image log
# 2017-05-14 13:21:40 has no image log
# 2017-05-14 13:26:40 has no image log
# 2017-05-14 13:31:40 has no image log
# 2017-05-14 13:36:40 has no image log
# 2017-05-14 13:41:40 has no image log
# 2017-05-14 13:46:40 has no image log
# 2017-05-14 13:51:40 has no image log
# 2017-05-14 13:56:40 has no image log
# 2017-05-16 06:05:00 has no image log
# 2017-05-16 06:10:00 has no image log
# 2017-05-16 06:15:00 has no image log
# 2017-05-16 06:20:00 has no image log
# 2017-05-16 06:25:00 has no image log
# 2017-05-16 06:30:00 has no image log
# 2017-05-16 06:35:00 has no image log
# 2017-05-16 06:40:00 has no image log
# 2017-05-16 06:45:00 has no image log
# 2017-05-16 06:50:00 has no image log
# 2017-05-16 06:55:00 has no image log
# 2017-05-16 07:00:00 has no image log
# 2017-05-16 07:05:00 has no image log
# 2017-05-16 07:10:00 has no image log
# 2017-05-16 07:15:00 has no image log
# 2017-05-16 07:20:00 has no image log
# 2017-05-16 07:25:00 has no image log
# 2017-05-16 08:13:20 has no image log
# 2017-05-16 08:18:20 has no image log
# 2017-05-16 08:23:20 has no image log
# 2017-05-16 08:28:20 has no image log
# 2017-05-16 08:33:20 has no image log
# 2017-05-16 08:38:20 has no image log
# 2017-05-16 08:43:20 has no image log
# 2017-05-16 08:48:20 has no image log
# 2017-05-16 08:51:40 has no image log
# 2017-05-16 08:56:40 has no image log
# 2017-05-16 09:01:40 has no image log
# 2017-05-16 09:06:40 has no image log
# 2017-05-16 09:11:40 has no image log
# 2017-05-16 09:16:40 has no image log
# 2017-05-16 09:21:40 has no image log
# 2017-05-16 09:26:40 has no image log
# 2017-05-16 09:31:40 has no image log
# 2017-05-16 12:45:00 has no image log
# 2017-05-16 12:50:00 has no image log
# 2017-05-16 12:55:00 has no image log
# 2017-05-16 13:00:00 has no image log
# 2017-05-16 13:05:00 has no image log
# 2017-05-16 13:10:00 has no image log
# 2017-05-16 13:15:00 has no image log
# processed 200/7163 images
# 2017-05-16 13:20:00 has no image log
# 2017-05-16 13:25:00 has no image log
# 2017-05-16 13:30:00 has no image log
# 2017-05-16 13:35:00 has no image log
# 2017-05-16 13:40:00 has no image log
# 2017-05-16 13:45:00 has no image log
# 2017-05-16 13:50:00 has no image log
# 2017-05-16 13:55:00 has no image log
# 2017-05-16 14:00:00 has no image log
# 2017-05-16 14:05:00 has no image log
# 2017-05-16 14:10:00 has no image log
# 2017-05-16 14:15:00 has no image log
# 2017-05-16 14:20:00 has no image log
# 2017-05-16 15:51:40 has no image log
# 2017-05-16 15:56:40 has no image log
# 2017-05-16 16:01:40 has no image log
# 2017-05-16 16:06:40 has no image log
# 2017-05-16 16:11:40 has no image log
# 2017-05-16 16:16:40 has no image log
# 2017-05-16 16:21:40 has no image log
# 2017-05-16 16:26:40 has no image log
# 2017-05-16 16:31:40 has no image log
# 2017-05-16 16:36:40 has no image log
# 2017-05-16 16:41:40 has no image log
# 2017-05-16 16:46:40 has no image log
# 2017-05-16 16:51:40 has no image log
# 2017-05-16 16:56:40 has no image log
# 2017-05-24 06:00:00 has no image log
# 2017-05-24 06:05:00 has no image log
# 2017-05-24 06:10:00 has no image log
# 2017-05-24 06:15:00 has no image log
# 2017-05-24 06:20:00 has no image log
# 2017-05-24 06:25:00 has no image log
# 2017-05-24 06:30:00 has no image log
# 2017-05-24 06:35:00 has no image log
# 2017-05-24 06:40:00 has no image log
# 2017-05-24 06:45:00 has no image log
# 2017-05-24 06:50:00 has no image log
# 2017-05-24 06:55:00 has no image log
# 2017-05-24 07:00:00 has no image log
# 2017-05-24 07:05:00 has no image log
# 2017-05-24 07:10:00 has no image log
# 2017-05-24 07:15:00 has no image log
# 2017-05-24 07:20:00 has no image log
# 2017-05-24 07:25:00 has no image log
# 2017-05-24 07:30:00 has no image log
# 2017-05-24 07:35:00 has no image log
# 2017-05-24 10:15:00 has no image log
# 2017-05-24 10:20:00 has no image log
# 2017-05-24 10:25:00 has no image log
# 2017-05-24 10:30:00 has no image log
# 2017-05-24 10:35:00 has no image log
# 2017-05-24 10:40:00 has no image log
# 2017-05-24 10:45:00 has no image log
# 2017-05-24 10:50:00 has no image log
# 2017-05-24 10:55:00 has no image log
# 2017-05-24 11:00:00 has no image log
# 2017-05-24 11:05:00 has no image log
# 2017-05-24 11:10:00 has no image log
# 2017-05-24 11:15:00 has no image log
# 2017-05-24 11:20:00 has no image log
# 2017-05-24 11:25:00 has no image log
# 2017-05-24 11:31:40 has no image log
# 2017-05-24 11:36:40 has no image log
# 2017-05-24 11:41:40 has no image log
# 2017-05-24 11:46:40 has no image log
# 2017-05-24 11:51:40 has no image log
# 2017-05-24 11:56:40 has no image log
# 2017-05-24 12:01:40 has no image log
# 2017-05-24 12:06:40 has no image log
# 2017-05-24 12:11:40 has no image log
# 2017-05-24 12:16:40 has no image log
# 2017-05-24 12:21:40 has no image log
# 2017-05-24 12:26:40 has no image log
# 2017-05-24 12:31:40 has no image log
# 2017-05-24 12:36:40 has no image log
# 2017-05-24 12:41:40 has no image log
# 2017-05-24 12:46:40 has no image log
# 2017-05-24 12:51:40 has no image log
# 2017-05-24 12:56:40 has no image log
# 2017-05-24 13:01:40 has no image log
# 2017-05-24 13:06:40 has no image log
# 2017-05-24 13:11:40 has no image log
# 2017-05-24 13:16:40 has no image log
# 2017-05-24 13:21:40 has no image log
# 2017-05-24 13:26:40 has no image log
# 2017-05-24 15:20:00 has no image log
# 2017-05-24 15:25:00 has no image log
# 2017-05-24 15:30:00 has no image log
# 2017-05-24 15:35:00 has no image log
# 2017-05-24 15:40:00 has no image log
# 2017-05-24 15:45:00 has no image log
# 2017-05-24 15:50:00 has no image log
# 2017-05-24 15:55:00 has no image log
# 2017-05-24 16:00:00 has no image log
# 2017-05-24 16:05:00 has no image log
# 2017-05-24 16:10:00 has no image log
# 2017-05-24 16:15:00 has no image log
# 2017-05-24 16:20:00 has no image log
# 2017-05-24 16:25:00 has no image log
# processed 300/7163 images
# 2017-05-24 16:30:00 has no image log
# 2017-05-24 16:35:00 has no image log
# 2017-05-24 16:40:00 has no image log
# 2017-05-24 16:45:00 has no image log
# 2017-05-24 16:50:00 has no image log
# 2017-05-24 16:55:00 has no image log
# 2017-05-24 17:00:00 has no image log
# 2017-05-24 17:03:20 has no image log
# 2017-05-24 17:08:20 has no image log
# 2017-05-24 17:13:20 has no image log
# 2017-05-24 17:18:20 has no image log
# 2017-05-24 17:23:20 has no image log
# 2017-05-24 17:28:20 has no image log
# 2017-05-24 17:33:20 has no image log
# 2017-05-24 17:38:20 has no image log
# 2017-05-26 18:33:20 has no image log
# 2017-05-26 18:38:20 has no image log
# 2017-05-26 18:43:20 has no image log
# 2017-05-26 18:48:20 has no image log
# 2017-05-26 18:53:20 has no image log
# 2017-05-26 18:58:20 has no image log
# 2017-05-26 19:03:20 has no image log
# 2017-05-26 19:08:20 has no image log
# 2017-05-26 19:13:20 has no image log
# 2017-05-26 19:18:20 has no image log
# 2017-05-26 19:23:20 has no image log
# 2017-05-26 19:28:20 has no image log
# 2017-05-26 19:33:20 has no image log
# 2017-05-26 19:38:20 has no image log
# 2017-05-27 06:00:00 has no image log
# 2017-05-27 06:05:00 has no image log
# 2017-05-27 06:10:00 has no image log
# 2017-05-27 06:15:00 has no image log
# 2017-05-27 06:20:00 has no image log
# 2017-05-27 06:25:00 has no image log
# 2017-05-27 06:30:00 has no image log
# 2017-05-27 06:35:00 has no image log
# 2017-05-27 06:40:00 has no image log
# 2017-05-27 06:45:00 has no image log
# 2017-05-27 06:50:00 has no image log
# 2017-05-27 06:55:00 has no image log
# 2017-05-27 07:00:00 has no image log
# 2017-05-27 07:05:00 has no image log
# 2017-05-27 07:10:00 has no image log
# processed 500/7163 images
# 2017-05-27 07:15:00 has no image log
# 2017-05-27 07:20:00 has no image log
# 2017-05-27 07:25:00 has no image log
# 2017-05-27 07:30:00 has no image log
# 2017-05-27 07:35:00 has no image log
# 2017-05-27 07:40:00 has no image log
# 2017-05-27 07:45:00 has no image log
# 2017-05-27 07:50:00 has no image log
# 2017-05-27 07:55:00 has no image log
# 2017-05-27 08:00:00 has no image log
# 2017-05-27 08:05:00 has no image log
# 2017-05-27 08:10:00 has no image log
# 2017-05-27 08:15:00 has no image log
# 2017-05-27 08:20:00 has no image log
# 2017-05-27 08:25:00 has no image log
# 2017-05-27 08:30:00 has no image log
# 2017-05-27 08:35:00 has no image log
# 2017-05-27 08:40:00 has no image log
# 2017-05-27 08:45:00 has no image log
# 2017-05-27 08:50:00 has no image log
# 2017-05-27 08:55:00 has no image log
# 2017-05-27 09:00:00 has no image log
# 2017-05-27 09:05:00 has no image log
# 2017-05-27 09:10:00 has no image log
# 2017-05-27 09:15:00 has no image log
# 2017-05-27 09:20:00 has no image log
# 2017-05-27 09:25:00 has no image log
# 2017-05-27 09:30:00 has no image log
# 2017-05-27 09:35:00 has no image log
# 2017-05-27 09:40:00 has no image log
# 2017-05-27 09:45:00 has no image log
# 2017-05-27 09:50:00 has no image log
# 2017-05-27 09:55:00 has no image log
# 2017-05-27 10:00:00 has no image log
# 2017-05-27 10:05:00 has no image log
# 2017-05-27 10:10:00 has no image log
# 2017-05-27 10:15:00 has no image log
# 2017-05-27 10:20:00 has no image log
# 2017-05-27 10:25:00 has no image log
# 2017-05-27 10:30:00 has no image log
# 2017-05-27 10:35:00 has no image log
# 2017-05-27 13:05:00 has no image log
# 2017-05-27 13:10:00 has no image log
# 2017-05-27 13:15:00 has no image log
# 2017-05-27 13:20:00 has no image log
# 2017-05-27 13:25:00 has no image log
# 2017-05-27 13:30:00 has no image log
# 2017-05-27 13:35:00 has no image log
# 2017-05-27 13:40:00 has no image log
# 2017-05-27 13:45:00 has no image log
# 2017-05-27 13:50:00 has no image log
# 2017-05-27 13:55:00 has no image log
# 2017-05-27 14:00:00 has no image log
# 2017-05-27 14:05:00 has no image log
# 2017-05-27 19:16:40 has no image log
# 2017-05-27 19:21:40 has no image log
# 2017-05-27 19:26:40 has no image log
# 2017-05-27 19:31:40 has no image log
# 2017-05-27 19:36:40 has no image log
# 2017-05-27 19:41:40 has no image log
# 2017-05-27 19:46:40 has no image log
# 2017-05-27 19:51:40 has no image log
# 2017-05-27 19:56:40 has no image log
# 2017-06-03 06:00:00 has no image log
# 2017-06-03 06:05:00 has no image log
# 2017-06-03 06:10:00 has no image log
# 2017-06-03 06:15:00 has no image log
# 2017-06-03 06:20:00 has no image log
# 2017-06-03 06:25:00 has no image log
# 2017-06-03 06:30:00 has no image log
# 2017-06-03 06:35:00 has no image log
# 2017-06-03 06:40:00 has no image log
# 2017-06-03 06:45:00 has no image log
# 2017-06-03 06:50:00 has no image log
# 2017-06-03 06:55:00 has no image log
# 2017-06-03 07:00:00 has no image log
# 2017-06-03 07:05:00 has no image log
# 2017-06-03 07:10:00 has no image log
# 2017-06-03 07:15:00 has no image log
# 2017-06-03 07:20:00 has no image log
# 2017-06-03 07:25:00 has no image log
# 2017-06-03 07:30:00 has no image log
# 2017-06-03 07:35:00 has no image log
# 2017-06-03 07:40:00 has no image log
# 2017-06-03 07:45:00 has no image log
# 2017-06-03 07:50:00 has no image log
# 2017-06-03 07:55:00 has no image log
# 2017-06-03 08:00:00 has no image log
# 2017-06-03 08:46:40 has no image log
# 2017-06-03 08:51:40 has no image log
# 2017-06-03 08:56:40 has no image log
# 2017-06-03 09:01:40 has no image log
# 2017-06-03 09:06:40 has no image log
# 2017-06-03 09:11:40 has no image log
# 2017-06-03 09:16:40 has no image log
# 2017-06-03 09:21:40 has no image log
# 2017-06-03 09:26:40 has no image log
# 2017-06-03 09:31:40 has no image log
# 2017-06-03 09:35:00 has no image log
# 2017-06-03 09:40:00 has no image log
# processed 600/7163 images
# 2017-06-03 09:45:00 has no image log
# 2017-06-03 09:50:00 has no image log
# 2017-06-03 09:55:00 has no image log
# 2017-06-03 10:00:00 has no image log
# 2017-06-03 10:05:00 has no image log
# 2017-06-03 10:10:00 has no image log
# 2017-06-03 10:15:00 has no image log
# 2017-06-03 10:20:00 has no image log
# 2017-06-03 10:25:00 has no image log
# 2017-06-03 10:30:00 has no image log
# 2017-06-03 10:35:00 has no image log
# 2017-06-03 10:40:00 has no image log
# 2017-06-03 10:45:00 has no image log
# 2017-06-03 10:50:00 has no image log
# 2017-06-03 10:55:00 has no image log
# 2017-06-03 11:00:00 has no image log
# 2017-06-03 11:05:00 has no image log
# 2017-06-03 11:10:00 has no image log
# 2017-06-03 11:15:00 has no image log
# 2017-06-03 11:20:00 has no image log
# 2017-06-03 11:25:00 has no image log
# 2017-06-03 11:30:00 has no image log
# 2017-06-03 11:35:00 has no image log
# 2017-06-03 11:40:00 has no image log
# 2017-06-03 11:45:00 has no image log
# 2017-06-03 11:50:00 has no image log
# 2017-06-13 12:20:00 has no image log
# 2017-06-13 12:25:00 has no image log
# 2017-06-13 12:30:00 has no image log
# 2017-06-13 12:35:00 has no image log
# 2017-06-13 12:40:00 has no image log
# 2017-06-13 12:45:00 has no image log
# 2017-06-13 12:50:00 has no image log
# 2017-06-13 12:55:00 has no image log
# 2017-06-13 13:00:00 has no image log
# 2017-06-13 13:05:00 has no image log
# 2017-06-13 13:10:00 has no image log
# 2017-06-13 13:15:00 has no image log
# 2017-06-13 13:20:00 has no image log
# 2017-06-13 13:25:00 has no image log
# 2017-06-13 14:15:00 has no image log
# 2017-06-13 14:20:00 has no image log
# 2017-06-13 14:25:00 has no image log
# 2017-06-13 14:30:00 has no image log
# 2017-06-13 14:35:00 has no image log
# 2017-06-13 14:40:00 has no image log
# 2017-06-13 14:45:00 has no image log
# 2017-06-13 14:50:00 has no image log
# 2017-06-13 14:55:00 has no image log
# 2017-06-13 15:00:00 has no image log
# 2017-06-13 15:05:00 has no image log
# 2017-06-13 15:10:00 has no image log
# 2017-06-14 06:00:00 has no image log
# 2017-06-14 06:05:00 has no image log
# 2017-06-14 06:10:00 has no image log
# 2017-06-14 06:15:00 has no image log
# 2017-06-14 06:20:00 has no image log
# 2017-06-14 06:25:00 has no image log
# 2017-06-14 06:30:00 has no image log
# 2017-06-14 06:35:00 has no image log
# 2017-06-14 06:40:00 has no image log
# 2017-06-14 06:45:00 has no image log
# 2017-06-14 06:50:00 has no image log
# 2017-06-14 06:55:00 has no image log
# 2017-06-14 07:00:00 has no image log
# 2017-06-14 07:05:00 has no image log
# 2017-06-14 07:10:00 has no image log
# 2017-06-14 07:15:00 has no image log
# 2017-06-14 07:20:00 has no image log
# 2017-06-14 07:25:00 has no image log
# 2017-06-14 07:30:00 has no image log
# 2017-06-14 07:35:00 has no image log
# 2017-06-14 07:40:00 has no image log
# 2017-06-14 07:45:00 has no image log
# 2017-06-14 07:50:00 has no image log
# 2017-06-14 07:55:00 has no image log
# 2017-06-14 08:00:00 has no image log
# 2017-06-14 08:05:00 has no image log
# 2017-06-14 08:10:00 has no image log
# 2017-06-14 08:15:00 has no image log
# 2017-06-14 08:20:00 has no image log
# 2017-06-14 08:25:00 has no image log
# 2017-06-14 08:30:00 has no image log
# 2017-06-14 08:35:00 has no image log
# 2017-06-14 08:40:00 has no image log
# 2017-06-14 08:45:00 has no image log
# 2017-06-14 08:50:00 has no image log
# 2017-06-14 08:55:00 has no image log
# processed 1000/7163 images
# For sampling frequency:  2  minutes
# Expected finishing time: 2022-05-22 01:05:02.317463
# 2017-06-14 09:00:00 has no image log
# 2017-06-14 09:05:00 has no image log
# 2017-06-14 09:10:00 has no image log
# 2017-06-14 09:15:00 has no image log
# 2017-06-14 09:20:00 has no image log
# 2017-06-14 09:25:00 has no image log
# 2017-06-14 09:30:00 has no image log
# 2017-06-14 09:35:00 has no image log
# 2017-06-14 09:40:00 has no image log
# 2017-06-14 09:45:00 has no image log
# 2017-06-14 09:50:00 has no image log
# 2017-06-14 09:55:00 has no image log
# 2017-06-14 10:00:00 has no image log
# 2017-06-14 10:05:00 has no image log
# 2017-06-14 10:10:00 has no image log
# 2017-06-14 10:15:00 has no image log
# 2017-06-14 13:08:20 has no image log
# 2017-06-14 13:13:20 has no image log
# 2017-06-14 13:18:20 has no image log
# 2017-06-14 13:23:20 has no image log
# 2017-06-14 13:28:20 has no image log
# 2017-06-14 13:33:20 has no image log
# 2017-06-14 13:38:20 has no image log
# 2017-06-14 13:43:20 has no image log
# 2017-06-14 14:31:40 has no image log
# 2017-06-14 14:36:40 has no image log
# 2017-06-14 14:41:40 has no image log
# 2017-06-14 14:46:40 has no image log
# 2017-06-14 14:51:40 has no image log
# 2017-06-14 14:56:40 has no image log
# 2017-06-14 15:01:40 has no image log
# 2017-06-14 15:06:40 has no image log
# 2017-06-14 15:11:40 has no image log
# 2017-06-14 15:16:40 has no image log
# 2017-06-14 15:21:40 has no image log
# 2017-06-14 15:26:40 has no image log
# 2017-06-14 15:31:40 has no image log
# 2017-06-14 15:36:40 has no image log
# 2017-06-14 15:40:00 has no image log
# 2017-06-14 15:45:00 has no image log
# 2017-06-14 15:50:00 has no image log
# 2017-06-14 15:55:00 has no image log
# 2017-06-14 16:00:00 has no image log
# 2017-06-14 16:05:00 has no image log
# 2017-06-14 16:10:00 has no image log
# 2017-06-14 16:15:00 has no image log
# 2017-06-14 16:20:00 has no image log
# 2017-06-14 16:25:00 has no image log
# 2017-06-14 16:30:00 has no image log
# 2017-06-14 16:35:00 has no image log
# 2017-06-14 16:40:00 has no image log
# 2017-06-14 16:45:00 has no image log
# 2017-06-14 16:50:00 has no image log
# 2017-06-14 16:55:00 has no image log
# 2017-06-14 17:00:00 has no image log
# 2017-06-14 17:05:00 has no image log
# 2017-06-14 17:10:00 has no image log
# 2017-06-14 17:15:00 has no image log
# 2017-06-14 17:20:00 has no image log
# 2017-06-14 17:25:00 has no image log
# 2017-06-14 17:30:00 has no image log
# 2017-06-14 17:35:00 has no image log
# 2017-06-14 17:40:00 has no image log
# 2017-06-14 17:45:00 has no image log
# 2017-06-14 17:50:00 has no image log
# 2017-06-14 17:55:00 has no image log
# 2017-06-14 18:00:00 has no image log
# 2017-06-14 18:05:00 has no image log
# 2017-06-14 18:10:00 has no image log
# 2017-06-14 18:15:00 has no image log
# 2017-06-14 18:20:00 has no image log
# 2017-06-14 18:25:00 has no image log
# 2017-06-14 18:30:00 has no image log
# 2017-06-14 18:35:00 has no image log
# 2017-06-14 18:40:00 has no image log
# 2017-06-14 18:45:00 has no image log
# 2017-06-14 18:50:00 has no image log
# 2017-06-14 18:55:00 has no image log
# 2017-06-14 19:00:00 has no image log
# 2017-06-14 19:05:00 has no image log
# 2017-06-14 19:10:00 has no image log
# 2017-06-14 19:15:00 has no image log
# 2017-06-14 19:20:00 has no image log
# 2017-06-14 19:25:00 has no image log
# 2017-06-14 19:30:00 has no image log
# 2017-06-14 19:35:00 has no image log
# 2017-06-14 19:40:00 has no image log
# 2017-06-14 19:45:00 has no image log
# 2017-06-14 19:50:00 has no image log
# 2017-06-14 19:55:00 has no image log
# 2017-06-24 06:00:00 has no PV pred
# 2017-06-24 06:00:00 has no image log
# 2017-06-24 06:46:40 has no image log
# 2017-06-24 06:51:40 has no image log
# 2017-06-24 06:56:40 has no image log
# 2017-06-24 07:01:40 has no image log
# 2017-06-24 07:06:40 has no image log
# 2017-06-24 07:11:40 has no image log
# 2017-06-24 07:16:40 has no image log
# 2017-06-24 07:21:40 has no image log
# 2017-06-24 07:26:40 has no image log
# processed 1100/7163 images
# 2017-06-24 07:31:40 has no image log
# 2017-06-24 07:36:40 has no image log
# 2017-06-24 07:41:40 has no image log
# 2017-06-24 07:46:40 has no image log
# 2017-06-24 07:51:40 has no image log
# 2017-06-24 07:56:40 has no image log
# 2017-06-24 08:01:40 has no image log
# 2017-06-24 08:06:40 has no image log
# 2017-06-24 08:11:40 has no image log
# 2017-06-24 08:16:40 has no image log
# 2017-06-24 08:21:40 has no image log
# 2017-06-24 08:26:40 has no image log
# 2017-06-24 08:31:40 has no image log
# 2017-06-24 08:36:40 has no image log
# 2017-06-24 08:41:40 has no image log
# 2017-06-24 08:46:40 has no image log
# 2017-06-24 08:51:40 has no image log
# 2017-06-24 08:56:40 has no image log
# 2017-06-24 09:01:40 has no image log
# 2017-06-24 09:06:40 has no image log
# 2017-06-24 09:10:00 has no image log
# 2017-06-24 09:15:00 has no image log
# 2017-06-24 09:20:00 has no image log
# 2017-06-24 09:25:00 has no image log
# 2017-06-24 09:30:00 has no image log
# 2017-06-24 09:35:00 has no image log
# 2017-06-24 09:40:00 has no image log
# 2017-06-24 09:45:00 has no image log
# 2017-06-24 09:50:00 has no image log
# 2017-06-24 09:55:00 has no image log
# 2017-06-24 10:00:00 has no image log
# 2017-06-24 10:05:00 has no image log
# 2017-06-24 10:10:00 has no image log
# 2017-06-24 10:15:00 has no image log
# 2017-06-24 10:20:00 has no image log
# 2017-06-24 10:25:00 has no image log
# 2017-06-24 10:30:00 has no image log
# 2017-06-24 10:35:00 has no image log
# 2017-06-24 10:40:00 has no image log
# 2017-06-24 10:45:00 has no image log
# 2017-06-24 10:50:00 has no image log
# 2017-06-24 10:55:00 has no image log
# 2017-06-24 11:00:00 has no image log
# 2017-06-24 11:05:00 has no image log
# 2017-06-24 11:10:00 has no image log
# 2017-06-24 11:15:00 has no image log
# 2017-06-24 11:20:00 has no image log
# 2017-06-24 11:25:00 has no image log
# 2017-06-24 11:30:00 has no image log
# 2017-06-24 11:35:00 has no image log
# 2017-06-24 11:40:00 has no image log
# 2017-06-24 11:45:00 has no image log
# 2017-06-24 11:50:00 has no image log
# 2017-06-24 11:55:00 has no image log
# 2017-06-24 12:00:00 has no image log
# 2017-06-24 12:05:00 has no image log
# 2017-06-24 12:10:00 has no image log
# 2017-06-24 12:16:40 has no image log
# 2017-06-24 12:21:40 has no image log
# 2017-06-24 12:26:40 has no image log
# 2017-06-24 12:31:40 has no image log
# 2017-06-24 12:36:40 has no image log
# 2017-06-24 12:41:40 has no image log
# 2017-06-24 12:46:40 has no image log
# 2017-06-24 12:51:40 has no image log
# 2017-06-24 12:56:40 has no image log
# 2017-06-24 13:01:40 has no image log
# 2017-06-24 13:06:40 has no image log
# 2017-06-24 13:11:40 has no image log
# 2017-06-24 13:16:40 has no image log
# 2017-06-24 15:11:40 has no image log
# 2017-06-24 15:16:40 has no image log
# 2017-06-24 15:21:40 has no image log
# 2017-06-24 15:26:40 has no image log
# 2017-06-24 15:31:40 has no image log
# 2017-06-24 15:36:40 has no image log
# 2017-06-24 15:41:40 has no image log
# 2017-06-24 15:46:40 has no image log
# 2017-06-24 15:51:40 has no image log
# 2017-06-24 15:56:40 has no image log
# 2017-06-24 16:01:40 has no image log
# 2017-06-24 16:06:40 has no image log
# 2017-06-24 16:11:40 has no image log
# 2017-06-24 16:16:40 has no image log
# 2017-06-24 16:21:40 has no image log
# 2017-06-24 16:26:40 has no image log
# 2017-06-24 16:31:40 has no image log
# 2017-06-24 16:33:20 has no image log
# 2017-06-24 16:38:20 has no image log
# 2017-06-24 16:43:20 has no image log
# 2017-06-24 16:48:20 has no image log
# 2017-06-24 16:53:20 has no image log
# 2017-06-24 16:58:20 has no image log
# 2017-06-24 17:03:20 has no image log
# 2017-06-24 17:08:20 has no image log
# 2017-06-24 17:13:20 has no image log
# 2017-06-24 17:18:20 has no image log
# 2017-06-24 17:23:20 has no image log
# 2017-06-24 17:28:20 has no image log
# 2017-06-24 17:33:20 has no image log
# processed 1200/7163 images
# 2017-06-24 17:38:20 has no image log
# 2017-06-24 17:40:00 has no image log
# 2017-06-24 17:45:00 has no image log
# 2017-06-24 17:50:00 has no image log
# 2017-06-24 17:55:00 has no image log
# 2017-06-24 18:00:00 has no image log
# 2017-06-24 18:05:00 has no image log
# 2017-06-24 18:10:00 has no image log
# 2017-06-24 18:15:00 has no image log
# 2017-06-24 18:20:00 has no image log
# 2017-06-24 18:25:00 has no image log
# 2017-06-24 18:30:00 has no image log
# 2017-06-24 18:35:00 has no image log
# 2017-06-24 18:40:00 has no image log
# 2017-06-24 18:45:00 has no image log
# 2017-06-24 18:50:00 has no image log
# 2017-06-24 18:55:00 has no image log
# 2017-06-24 19:00:00 has no image log
# 2017-06-24 19:05:00 has no image log
# 2017-06-24 19:10:00 has no image log
# 2017-06-24 19:15:00 has no image log
# 2017-06-24 19:20:00 has no image log
# 2017-06-24 19:25:00 has no image log
# 2017-06-24 19:26:40 has no image log
# 2017-06-24 19:31:40 has no image log
# 2017-06-24 19:36:40 has no image log
# 2017-06-24 19:41:40 has no image log
# 2017-06-24 19:46:40 has no image log
# 2017-06-24 19:51:40 has no image log
# 2017-06-24 19:56:40 has no image log
# 2017-06-25 06:00:00 has no image log
# 2017-06-25 06:05:00 has no image log
# 2017-06-25 06:10:00 has no image log
# 2017-06-25 06:15:00 has no image log
# 2017-06-25 06:20:00 has no image log
# 2017-06-25 06:25:00 has no image log
# 2017-06-25 06:30:00 has no image log
# 2017-06-25 06:35:00 has no image log
# 2017-06-25 06:40:00 has no image log
# 2017-06-25 06:45:00 has no image log
# 2017-06-25 06:50:00 has no image log
# 2017-06-25 06:55:00 has no image log
# 2017-06-25 07:00:00 has no image log
# 2017-06-25 07:05:00 has no image log
# 2017-06-25 07:10:00 has no image log
# 2017-06-25 07:15:00 has no image log
# 2017-06-25 07:16:40 has no image log
# 2017-06-25 07:21:40 has no image log
# 2017-06-25 07:26:40 has no image log
# 2017-06-25 07:31:40 has no image log
# 2017-06-25 07:36:40 has no image log
# 2017-06-25 07:41:40 has no image log
# 2017-06-25 07:46:40 has no image log
# 2017-06-25 07:51:40 has no image log
# 2017-06-25 07:56:40 has no image log
# 2017-06-25 08:01:40 has no image log
# 2017-06-25 08:06:40 has no image log
# 2017-06-25 08:11:40 has no image log
# 2017-06-25 08:16:40 has no image log
# 2017-06-25 08:21:40 has no image log
# 2017-06-25 08:26:40 has no image log
# 2017-06-25 08:31:40 has no image log
# 2017-06-25 08:36:40 has no image log
# 2017-06-25 08:41:40 has no image log
# 2017-06-25 08:46:40 has no image log
# 2017-06-25 08:51:40 has no image log
# 2017-06-25 08:56:40 has no image log
# 2017-06-25 09:01:40 has no image log
# 2017-06-25 09:06:40 has no image log
# 2017-06-25 09:11:40 has no image log
# 2017-06-25 09:16:40 has no image log
# 2017-06-25 09:21:40 has no image log
# 2017-06-25 09:26:40 has no image log
# 2017-06-25 11:35:00 has no image log
# 2017-06-25 11:40:00 has no image log
# 2017-06-25 11:45:00 has no image log
# 2017-06-25 11:50:00 has no image log
# 2017-06-25 11:55:00 has no image log
# 2017-06-25 12:00:00 has no image log
# 2017-06-25 12:05:00 has no image log
# 2017-06-25 12:10:00 has no image log
# 2017-06-25 12:15:00 has no image log
# 2017-06-25 13:41:40 has no image log
# 2017-06-25 13:46:40 has no image log
# ...
# 2017-11-02 12:20:00 has no image log
# 2017-11-02 12:25:00 has no image log
# 2017-11-02 12:30:00 has no image log
# 2017-11-02 12:35:00 has no image log
# 2017-11-02 12:40:00 has no image log
# 2017-11-02 12:45:00 has no image log
# 2017-11-02 12:50:00 has no image log
# 2017-11-02 12:55:00 has no image log
# 2017-11-02 13:00:00 has no image log
# 2017-11-02 13:05:00 has no image log
# 2017-11-02 13:10:00 has no image log
# 2017-11-02 13:15:00 has no image log
# 2017-11-02 13:20:00 has no image log
# 2017-11-02 13:25:00 has no image log
# 2017-11-02 13:30:00 has no image log
# 2017-11-02 13:35:00 has no image log
# 2017-11-02 13:40:00 has no image log
# 2017-11-02 13:45:00 has no image log
# 2017-11-02 13:50:00 has no image log
# 2017-11-02 13:55:00 has no image log
# 2017-11-02 14:00:00 has no image log
# 2017-11-02 14:05:00 has no image log
# 2017-11-02 14:10:00 has no image log
# 2017-11-02 14:15:00 has no image log
# 2017-11-02 14:20:00 has no image log
# 2017-11-02 14:25:00 has no image log
# 2017-11-02 14:30:00 has no image log
# 2017-11-02 14:35:00 has no image log
# 2017-11-02 14:40:00 has no image log
# 2017-11-02 14:45:00 has no image log
# 2017-11-02 14:50:00 has no image log
# 2017-11-02 14:55:00 has no image log
# 2017-11-02 15:00:00 has no image log
# 2017-11-02 15:05:00 has no image log
# 2017-11-02 15:10:00 has no image log
# 2017-11-02 15:15:00 has no image log
# 2017-11-02 15:20:00 has no image log
# 2017-11-02 15:25:00 has no image log
# 2017-11-02 15:30:00 has no image log
# 2017-11-02 15:35:00 has no image log
# 2017-11-02 15:40:00 has no image log
# 2017-11-02 15:45:00 has no image log
# 2017-11-02 15:50:00 has no image log
# 2017-11-02 15:55:00 has no image log
# 2017-11-02 16:00:00 has no image log
# 2017-11-02 16:05:00 has no image log
# 2017-11-02 16:10:00 has no image log
# 2017-11-02 16:15:00 has no image log
# 2017-11-02 16:20:00 has no image log
# 2017-11-02 16:25:00 has no image log
# 2017-11-02 16:30:00 has no image log
# 2017-11-02 16:35:00 has no image log
# 2017-11-02 16:40:00 has no image log
# 2017-11-02 16:45:00 has no image log
# 2017-11-02 16:50:00 has no image log
# 2017-11-02 16:55:00 has no image log
# 2017-11-02 17:00:00 has no image log
# 2017-11-02 17:05:00 has no image log
# processed 6800/7163 images
# 2017-11-02 17:10:00 has no image log
# 2017-11-02 17:15:00 has no image log
# 2017-11-02 17:20:00 has no image log
# 2017-11-02 17:25:00 has no image log
# 2017-11-02 17:30:00 has no image log
# 2017-11-02 17:35:00 has no image log
# 2017-11-02 17:40:00 has no image log
# 2017-11-02 17:45:00 has no image log
# 2017-11-02 17:50:00 has no image log
# 2017-11-02 17:55:00 has no image log
# 2017-11-02 18:00:00 has no image log
# 2017-11-02 18:05:00 has no image log
# 2017-11-02 18:10:00 has no image log
# 2017-11-02 18:15:00 has no image log
# 2017-11-02 18:20:00 has no image log
# 2017-11-02 18:25:00 has no image log
# 2017-11-02 18:30:00 has no image log
# 2017-11-02 18:35:00 has no image log
# 2017-11-02 18:40:00 has no image log
# 2017-11-02 18:45:00 has no image log
# 2017-11-02 18:50:00 has no image log
# 2017-11-02 18:55:00 has no image log
# 2017-11-02 19:00:00 has no image log
# 2017-11-02 19:05:00 has no image log
# 2017-11-02 19:10:00 has no image log
# 2017-11-02 19:15:00 has no image log
# 2017-11-02 19:20:00 has no image log
# 2017-11-02 19:25:00 has no image log
# 2017-11-02 19:30:00 has no image log
# 2017-11-02 19:40:00 has no image log
# 2017-11-02 19:45:00 has no image log
# 2017-11-02 19:50:00 has no image log
# 2017-11-02 19:55:00 has no image log
# 2017-11-03 06:00:00 has no image log
# 2017-11-03 06:05:00 has no image log
# 2017-11-03 06:10:00 has no image log
# 2017-11-03 06:15:00 has no image log
# 2017-11-03 06:20:00 has no image log
# 2017-11-03 06:25:00 has no image log
# 2017-11-03 06:30:00 has no image log
# 2017-11-03 06:35:00 has no image log
# 2017-11-03 06:40:00 has no image log
# 2017-11-03 06:45:00 has no image log
# 2017-11-03 06:50:00 has no image log
# 2017-11-03 06:55:00 has no image log
# 2017-11-03 07:00:00 has no image log
# 2017-11-03 07:05:00 has no image log
# 2017-11-03 07:10:00 has no image log
# 2017-11-03 07:15:00 has no image log
# 2017-11-03 07:20:00 has no image log
# 2017-11-03 07:25:00 has no image log
# 2017-11-03 07:30:00 has no image log
# 2017-11-03 07:35:00 has no image log
# 2017-11-03 07:40:00 has no image log
# 2017-11-03 07:45:00 has no image log
# 2017-11-03 07:50:00 has no image log
# 2017-11-03 07:55:00 has no image log
# 2017-11-03 08:00:00 has no image log
# 2017-11-03 08:05:00 has no image log
# 2017-11-03 08:10:00 has no image log
# 2017-11-03 08:15:00 has no image log
# 2017-11-03 08:20:00 has no image log
# 2017-11-03 08:25:00 has no image log
# 2017-11-03 08:30:00 has no image log
# 2017-11-03 08:35:00 has no image log
# 2017-11-03 08:40:00 has no image log
# 2017-11-03 08:45:00 has no image log
# 2017-11-03 08:50:00 has no image log
# 2017-11-03 08:55:00 has no image log
# 2017-11-03 09:00:00 has no image log
# 2017-11-03 09:05:00 has no image log
# 2017-11-03 09:10:00 has no image log
# 2017-11-03 09:15:00 has no image log
# 2017-11-03 09:20:00 has no image log
# 2017-11-03 09:25:00 has no image log
# 2017-11-03 09:30:00 has no image log
# 2017-11-03 09:35:00 has no image log
# 2017-11-03 09:40:00 has no image log
# 2017-11-03 09:45:00 has no image log
# 2017-11-03 09:50:00 has no image log
# 2017-11-03 09:55:00 has no image log
# 2017-11-03 10:00:00 has no image log
# 2017-11-03 10:05:00 has no image log
# 2017-11-03 10:10:00 has no image log
# 2017-11-03 10:15:00 has no image log
# 2017-11-03 10:20:00 has no image log
# 2017-11-03 10:55:00 has no image log
# 2017-11-03 11:00:00 has no image log
# 2017-11-03 11:05:00 has no image log
# 2017-11-03 11:10:00 has no image log
# 2017-11-03 11:15:00 has no image log
# 2017-11-03 11:20:00 has no image log
# 2017-11-03 11:25:00 has no image log
# 2017-11-03 11:30:00 has no image log
# 2017-11-03 11:35:00 has no image log
# 2017-11-03 11:40:00 has no image log
# 2017-11-03 11:45:00 has no image log
# 2017-11-03 11:50:00 has no image log
# 2017-11-03 11:55:00 has no image log
# 2017-11-03 12:00:00 has no image log
# processed 6900/7163 images
# 2017-11-03 12:05:00 has no image log
# 2017-11-03 12:10:00 has no image log
# 2017-11-03 12:15:00 has no image log
# 2017-11-03 12:20:00 has no image log
# 2017-11-03 12:25:00 has no image log
# 2017-11-03 12:30:00 has no image log
# 2017-11-03 12:35:00 has no image log
# 2017-11-03 12:40:00 has no image log
# 2017-11-03 12:45:00 has no image log
# 2017-11-03 12:50:00 has no image log
# 2017-11-03 12:55:00 has no image log
# 2017-11-03 13:00:00 has no image log
# 2017-11-03 13:05:00 has no image log
# 2017-11-03 13:10:00 has no image log
# 2017-11-03 13:15:00 has no image log
# 2017-11-03 13:20:00 has no image log
# 2017-11-03 13:25:00 has no image log
# 2017-11-03 13:30:00 has no image log
# 2017-11-03 13:35:00 has no image log
# 2017-11-03 13:40:00 has no image log
# 2017-11-03 13:45:00 has no image log
# 2017-11-03 13:50:00 has no image log
# 2017-11-03 13:55:00 has no image log
# 2017-11-03 14:00:00 has no image log
# 2017-11-03 14:05:00 has no image log
# 2017-11-03 14:10:00 has no image log
# 2017-11-03 14:15:00 has no image log
# 2017-11-03 14:20:00 has no image log
# 2017-11-03 14:25:00 has no image log
# 2017-11-03 14:30:00 has no image log
# 2017-11-03 14:35:00 has no image log
# 2017-11-03 14:40:00 has no image log
# 2017-11-03 14:45:00 has no image log
# 2017-11-03 14:50:00 has no image log
# 2017-11-03 14:55:00 has no image log
# 2017-11-03 15:00:00 has no image log
# 2017-11-03 15:05:00 has no image log
# 2017-11-03 15:10:00 has no image log
# 2017-11-03 15:15:00 has no image log
# 2017-11-03 15:20:00 has no image log
# 2017-11-03 15:25:00 has no image log
# 2017-11-03 15:30:00 has no image log
# 2017-11-03 15:35:00 has no image log
# 2017-11-03 15:40:00 has no image log
# 2017-11-03 15:45:00 has no image log
# 2017-11-03 15:50:00 has no image log
# 2017-11-03 15:55:00 has no image log
# 2017-11-03 16:00:00 has no image log
# 2017-11-03 16:05:00 has no image log
# 2017-11-03 16:10:00 has no image log
# 2017-11-03 16:15:00 has no image log
# 2017-11-03 16:20:00 has no image log
# 2017-11-03 16:25:00 has no image log
# 2017-11-03 16:30:00 has no image log
# 2017-11-03 16:35:00 has no image log
# 2017-11-03 16:40:00 has no image log
# 2017-11-03 16:45:00 has no image log
# 2017-11-03 16:50:00 has no image log
# 2017-11-03 16:55:00 has no image log
# 2017-11-03 17:00:00 has no image log
# 2017-11-03 17:05:00 has no image log
# 2017-11-03 17:10:00 has no image log
# 2017-11-03 17:15:00 has no image log
# 2017-11-03 17:20:00 has no image log
# 2017-11-03 17:25:00 has no image log
# 2017-11-03 17:30:00 has no image log
# 2017-11-03 17:35:00 has no image log
# 2017-11-03 17:40:00 has no image log
# 2017-11-03 17:45:00 has no image log
# 2017-11-03 17:50:00 has no image log
# 2017-11-03 17:55:00 has no image log
# 2017-11-03 18:00:00 has no image log
# 2017-11-03 18:05:00 has no image log
# 2017-11-03 18:10:00 has no image log
# 2017-11-03 18:15:00 has no image log
# 2017-11-03 18:20:00 has no image log
# 2017-11-03 18:25:00 has no image log
# 2017-11-03 18:30:00 has no image log
# 2017-11-03 18:35:00 has no image log
# 2017-11-03 18:40:00 has no image log
# 2017-11-03 18:45:00 has no image log
# 2017-11-03 18:50:00 has no image log
# 2017-11-03 18:55:00 has no image log
# 2017-11-03 19:00:00 has no image log
# 2017-11-03 19:05:00 has no image log
# 2017-11-03 19:10:00 has no image log
# 2017-11-03 19:15:00 has no image log
# 2017-11-03 19:20:00 has no image log
# 2017-11-03 19:25:00 has no image log
# 2017-11-03 19:30:00 has no image log
# 2017-11-03 19:35:00 has no image log
# 2017-11-03 19:40:00 has no image log
# 2017-11-03 19:45:00 has no image log
# 2017-11-03 19:50:00 has no image log
# 2017-11-03 19:55:00 has no image log
# 2017-12-30 06:00:00 has no image log
# 2017-12-30 06:05:00 has no image log
# 2017-12-30 06:10:00 has no image log
# 2017-12-30 06:15:00 has no image log
# 2017-12-30 06:20:00 has no image log
# processed 7000/7163 images
# For sampling frequency:  2  minutes
# Expected finishing time: 2022-05-22 01:05:02.857433
# 2017-12-30 06:25:00 has no image log
# 2017-12-30 06:30:00 has no image log
# 2017-12-30 06:35:00 has no image log
# 2017-12-30 06:40:00 has no image log
# 2017-12-30 06:45:00 has no image log
# 2017-12-30 06:50:00 has no image log
# 2017-12-30 06:55:00 has no image log
# 2017-12-30 07:00:00 has no image log
# 2017-12-30 07:05:00 has no image log
# 2017-12-30 07:10:00 has no image log
# 2017-12-30 07:15:00 has no image log
# 2017-12-30 07:20:00 has no image log
# 2017-12-30 07:25:00 has no image log
# 2017-12-30 07:30:00 has no image log
# 2017-12-30 07:35:00 has no image log
# 2017-12-30 07:40:00 has no image log
# 2017-12-30 07:45:00 has no image log
# 2017-12-30 07:50:00 has no image log
# 2017-12-30 07:55:00 has no image log
# 2017-12-30 08:00:00 has no image log
# 2017-12-30 08:05:00 has no image log
# 2017-12-30 08:10:00 has no image log
# 2017-12-30 08:15:00 has no image log
# 2017-12-30 08:20:00 has no image log
# 2017-12-30 08:25:00 has no image log
# 2017-12-30 08:30:00 has no image log
# 2017-12-30 08:35:00 has no image log
# 2017-12-30 08:40:00 has no image log
# 2017-12-30 08:45:00 has no image log
# 2017-12-30 08:50:00 has no image log
# 2017-12-30 08:55:00 has no image log
# 2017-12-30 09:00:00 has no image log
# 2017-12-30 09:05:00 has no image log
# 2017-12-30 09:10:00 has no image log
# 2017-12-30 09:15:00 has no image log
# 2017-12-30 09:20:00 has no image log
# 2017-12-30 09:25:00 has no image log
# 2017-12-30 09:30:00 has no image log
# 2017-12-30 09:35:00 has no image log
# 2017-12-30 09:40:00 has no image log
# 2017-12-30 09:45:00 has no image log
# 2017-12-30 09:50:00 has no image log
# 2017-12-30 09:55:00 has no image log
# 2017-12-30 10:00:00 has no image log
# 2017-12-30 10:05:00 has no image log
# 2017-12-30 10:10:00 has no image log
# 2017-12-30 10:15:00 has no image log
# 2017-12-30 10:20:00 has no image log
# 2017-12-30 10:25:00 has no image log
# 2017-12-30 10:30:00 has no image log
# 2017-12-30 10:35:00 has no image log
# 2017-12-30 10:40:00 has no image log
# 2017-12-30 10:45:00 has no image log
# 2017-12-30 10:50:00 has no image log
# 2017-12-30 10:55:00 has no image log
# 2017-12-30 11:00:00 has no image log
# 2017-12-30 11:05:00 has no image log
# 2017-12-30 11:10:00 has no image log
# 2017-12-30 11:15:00 has no image log
# 2017-12-30 11:20:00 has no image log
# 2017-12-30 11:25:00 has no image log
# 2017-12-30 11:30:00 has no image log
# 2017-12-30 11:35:00 has no image log
# 2017-12-30 11:40:00 has no image log
# 2017-12-30 11:45:00 has no image log
# 2017-12-30 11:50:00 has no image log
# 2017-12-30 11:55:00 has no image log
# 2017-12-30 12:00:00 has no image log
# 2017-12-30 12:05:00 has no image log
# 2017-12-30 12:10:00 has no image log
# 2017-12-30 12:15:00 has no image log
# 2017-12-30 12:20:00 has no image log
# 2017-12-30 12:25:00 has no image log
# 2017-12-30 12:30:00 has no image log
# 2017-12-30 12:35:00 has no image log
# 2017-12-30 12:40:00 has no image log
# 2017-12-30 12:45:00 has no image log
# 2017-12-30 12:50:00 has no image log
# 2017-12-30 12:55:00 has no image log
# 2017-12-30 13:00:00 has no image log
# 2017-12-30 13:05:00 has no image log
# 2017-12-30 13:10:00 has no image log
# 2017-12-30 13:15:00 has no image log
# 2017-12-30 13:20:00 has no image log
# 2017-12-30 13:25:00 has no image log
# 2017-12-30 13:30:00 has no image log
# 2017-12-30 13:35:00 has no image log
# 2017-12-30 13:40:00 has no image log
# 2017-12-30 13:45:00 has no image log
# 2017-12-30 13:50:00 has no image log
# 2017-12-30 13:55:00 has no image log
# 2017-12-30 14:00:00 has no image log
# 2017-12-30 14:05:00 has no image log
# 2017-12-30 14:10:00 has no image log
# 2017-12-30 14:15:00 has no image log
# 2017-12-30 14:20:00 has no image log
# 2017-12-30 14:25:00 has no image log
# 2017-12-30 14:30:00 has no image log
# 2017-12-30 14:35:00 has no image log
# 2017-12-30 14:40:00 has no image log
# processed 7100/7163 images
# 2017-12-30 14:45:00 has no image log
# 2017-12-30 14:50:00 has no image log
# 2017-12-30 14:55:00 has no image log
# 2017-12-30 15:00:00 has no image log
# 2017-12-30 15:05:00 has no image log
# 2017-12-30 15:10:00 has no image log
# 2017-12-30 15:15:00 has no image log
# 2017-12-30 15:20:00 has no image log
# 2017-12-30 15:25:00 has no image log
# 2017-12-30 15:30:00 has no image log
# 2017-12-30 15:35:00 has no image log
# 2017-12-30 15:40:00 has no image log
# 2017-12-30 15:45:00 has no image log
# 2017-12-30 15:50:00 has no image log
# 2017-12-30 15:55:00 has no image log
# 2017-12-30 16:00:00 has no image log
# 2017-12-30 16:05:00 has no image log
# 2017-12-30 16:10:00 has no image log
# 2017-12-30 16:15:00 has no image log
# 2017-12-30 16:20:00 has no image log
# 2017-12-30 16:25:00 has no image log
# 2017-12-30 16:30:00 has no image log
# 2017-12-30 16:35:00 has no image log
# 2017-12-30 16:40:00 has no image log
# 2017-12-30 16:45:00 has no image log
# 2017-12-30 16:50:00 has no image log
# 2017-12-30 16:55:00 has no image log
# 2017-12-30 17:00:00 has no image log
# 2017-12-30 17:05:00 has no image log
# 2017-12-30 17:10:00 has no image log
# 2017-12-30 17:15:00 has no image log
# 2017-12-30 17:20:00 has no image log
# 2017-12-30 17:25:00 has no image log
# 2017-12-30 17:30:00 has no image log
# 2017-12-30 17:40:00 has no image log
# 2017-12-30 17:45:00 has no image log
# 2017-12-30 17:50:00 has no image log
# 2017-12-30 17:55:00 has no image log
# 2017-12-30 18:00:00 has no image log
# 2017-12-30 18:05:00 has no image log
# 2017-12-30 18:10:00 has no image log
# 2017-12-30 18:15:00 has no image log
# 2017-12-30 18:20:00 has no image log
# 2017-12-30 18:25:00 has no image log
# 2017-12-30 18:30:00 has no image log
# 2017-12-30 18:35:00 has no image log
# 2017-12-30 18:40:00 has no image log
# 2017-12-30 18:45:00 has no image log
# 2017-12-30 18:50:00 has no image log
# 2017-12-30 18:55:00 has no image log
# 2017-12-30 19:00:00 has no image log
# 2017-12-30 19:05:00 has no image log
# 2017-12-30 19:10:00 has no image log
# 2017-12-30 19:15:00 has no image log
# 2017-12-30 19:20:00 has no image log
# 2017-12-30 19:25:00 has no image log
# 2017-12-30 19:30:00 has no image log
# 2017-12-30 19:35:00 has no image log
# 2017-12-30 19:40:00 has no image log
# 2017-12-30 19:45:00 has no image log
# 2017-12-30 19:50:00 has no image log
# 2017-12-30 19:55:00 has no image log
# times_trainval.shape (0,)
# image_log_trainval.shape (0, 16, 64, 64, 3)
# pv_log_trainval.shape (0, 16)
# pv_pred_trainval.shape (0,)
# times_test.shape (0,)
# image_log_test.shape (0, 16, 64, 64, 3)
# pv_log_test.shape (0, 16)
# pv_pred_test.shape (0,)
